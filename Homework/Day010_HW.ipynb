# %%
import requests
from bs4 import BeautifulSoup
r1 = requests.get("https://www.dcard.tw/f")

headers = {'user-agent':'my-app/0.01'}
r2 = requests.get("https://www.zhihu.com/explore",headers=headers)

response = r1.text
response1 = r2.text
print(type(response))

#印出 Dcard 的 html 內容（已經整理過） 
soup = BeautifulSoup(response)
print(soup.prettify())
# Out:
# <class 'str'>
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
#   <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>
#   <link crossorigin="true" href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="https://megapx-assets.dcard.tw" rel="dns-prefetch"/>
#   <link href="https://gcs.dcard.tw" rel="dns-prefetch"/>
#   <link href="https://imgur.dcard.tw" rel="dns-prefetch"/>
#   <link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="preload"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="Dcard" property="al:ios:app_name"/>
#   <meta content="Dcard" property="al:android:app_name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="951353454" property="al:ios:app_store_id"/>
#   <meta content="com.sparkslab.dcardreader" property="al:android:package"/>
#   <link href="/_next/static/manifest-dcard.json" rel="manifest"/>
#   <link href="/_next/static/media/dcard-icon-48-ed236519a9f1e19ecd7a05bbc43216c9.png" rel="icon" sizes="48x48" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-96-67d4c5f6a7cc6026406b70304936937d.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-144-f12595f1f04d1d78159ea1a26d952990.png" rel="icon" sizes="144x144" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-192-9f379614ba04e71a6c6c565457e0c389.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-57-6abc10d866571c5134884eab30bde2b0.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-72-29f99c18ac7c1c612d11d2a55b423607.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-76-74656fc06f60d610b228e1038a365eed.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-114-58a826f20cd08881308375de7b7ce582.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-120-00822c733e25ba05959c53cd12fafd04.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-144-f12595f1f04d1d78159ea1a26d952990.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-152-71d20896c5fce660606daf647a03d34f.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-180-e56647b6c84a0dc38a2065587576fcae.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
#   <link href="/_next/static/media/dcard-icon-48-ed236519a9f1e19ecd7a05bbc43216c9.png" rel="shortcut icon" type="image/png"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="twitter:description"/>
#   <meta content="https://www.dcard.tw/images/dcard-landing.png" itemprop="image" name="image"/>
#   <meta content="https://www.dcard.tw/images/dcard-landing.png" property="og:image"/>
#   <meta content="https://www.dcard.tw/images/dcard-landing.png" property="og:image:secure_url"/>
#   <meta content="https://www.dcard.tw/images/dcard-landing.png" property="twitter:image"/>
#   <link as="image" href="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg" rel="preload"/>
#   <title>
#    Dcard
#   </title>
#   <link href="https://www.dcard.tw/f" rel="canonical"/>
#   <meta content="https://www.dcard.tw/f" itemprop="url" name="url"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, viewport-fit=cover" name="viewport"/>
#   <link href="https://www.dcard.tw/f" hreflang="x-default" rel="alternate"/>
#   <meta content="Dcard" property="og:site_name"/>
#   <meta content="Dcard" property="og:title"/>
#   <meta content="https://www.dcard.tw/f" property="og:url"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="Dcard" name="twitter:title"/>
#   <meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/>
#   <meta content="dcard://category" property="al:ios:url"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"Organization","name":"Dcard","url":"https://www.dcard.tw","logo":{"@type":"ImageObject","url":"https://www.dcard.tw/_next/static/media/dcard-icon-512-0d203c9368792960c3dd89d81401c1f5.png","width":"512","height":"512"}}
#   </script>
#   <link href="https://bilanx.dcard.tw" rel="dns-prefetch"/>
#   <link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://certify.alexametrics.com" rel="dns-prefetch"/>
#   <link href="https://certify-js.alexametrics.com" rel="dns-prefetch"/>
#   <link as="script" href="https://certify-js.alexametrics.com/atrk.js" rel="preload"/>
#   <script>
#    _atrk_opts = { atrk_acct:"gj89j1a8Dy000J", domain:"dcard.tw",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#   </script>
#   <script>
#    window.dataLayer=window.dataLayer||[];window.dataLayer.push({'gtm.start':Date.now(),event:'gtm.js'});
#   </script>
#   <link as="script" href="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M" rel="preload"/>
#   <script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M">
#   </script>
#   <script>
#    (function(d){var a=d.domain.match(/^[-\w]+(?:\.pullup)?\.((?:dcard\.(?:cc|hk|io|tw)|dtto\.(?:com|io)))$/);if(a){d.domain=a[1]}})(document);
#   </script>
#   <meta content="56" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/ec828c8802a2573a3dbc.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/ec828c8802a2573a3dbc.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <link as="script" href="/_next/static/chunks/9947.fb9060f9ed04fb2629cf.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7100-7b499aeb928a9be4c3b2.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1700.78fe7a6548a3b8233069.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/3555.58ca4dfa69b8a6ae79ba.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/8113.2144ecfdce71ccb41a23.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1243.e7924db11cc0d5186be6.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/5835.1e8eb340807aeda3010a.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons-01bb11fe342ffe07589b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/3128.9da6ff9ebb87e7cec89b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7056-5fa799a911f2474cf143.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/5723.acef286ce256a481df08.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/webpack-b633320a3c54f0b22c27.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/framework-56dc96a11889c53d8326.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/main-67488740558d7ef5d8cf.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/_app-6a9c10df246259e5038f.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons-01bb11fe342ffe07589b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/3021-15ce5b0cbf5ba2feadf9.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/2931-a7c0e4aebad7fef770b1.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/8096-27196a1723934def68ec.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/8455-2f2b6c6d411b39f5915c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/5313-c53007ced109ee5f330d.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1623-64149042125b337fb0c2.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7056-5fa799a911f2474cf143.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6991-a27bd903d14e2050dde3.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6473-6c9e9b3cdc4f4603ee03.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/8538-e16e7ce3c889c466f92b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7570-aea065b5935a0f692ea2.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/forum-a9b8fc7def4f74ca9837.js" rel="preload"/>
#   <style data-styled="" data-styled-version="5.2.3">
#    body{background-color:#00324e;}/*!sc*/
# data-styled.g1[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .dvqhOE{fill:#e1e1e1;stroke:none;-webkit-transition:fill 0.15s cubic-bezier(0.4,0,0.2,1);transition:fill 0.15s cubic-bezier(0.4,0,0.2,1);object-fit:cover;display:inline-block;}/*!sc*/
# data-styled.g2[id="sc-husrwi"]{content:"dvqhOE,"}/*!sc*/
# .gVUpsb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .gVUpsb form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g3[id="dj0ioy-0"]{content:"gVUpsb,"}/*!sc*/
# .fysraG{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;outline:none;height:100%;padding:0 8px;font-size:14px;color:#fff;}/*!sc*/
# .fysraG::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fysraG::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g5[id="dj0ioy-2"]{content:"fysraG,"}/*!sc*/
# .kacUhU{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g6[id="dj0ioy-3"]{content:"kacUhU,"}/*!sc*/
# .dAVCLF{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g11[id="pkcmwm-0"]{content:"dAVCLF,"}/*!sc*/
# .dzaAJe{position:relative;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .dzaAJe:hover{color:rgba(0,0,0,1);}/*!sc*/
# .dzaAJe::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .jlRzxR{position:relative;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .jlRzxR:hover{color:rgba(0,0,0,1);}/*!sc*/
# .jlRzxR::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g12[id="pkcmwm-1"]{content:"dzaAJe,jlRzxR,"}/*!sc*/
# .idVSLh{--track-radius:3px;--track-size:8px;overflow:auto;width:100%;height:100%;}/*!sc*/
# data-styled.g29[id="sc-qz0f8b"]{content:"idVSLh,"}/*!sc*/
# .eRQARU{border-radius:var(--track-radius);background:transparent;-webkit-transition:background 200ms;transition:background 200ms;pointer-events:unset;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .simplebar-dragging .sc-bdvvaa,.eRQARU:hover{background:rgba(0,0,0,0.3);}/*!sc*/
# .eRQARU.simplebar-horizontal{height:var(--track-size);}/*!sc*/
# .eRQARU.simplebar-vertical{width:var(--track-size);}/*!sc*/
# data-styled.g30[id="sc-bdvvaa"]{content:"eRQARU,"}/*!sc*/
# .bhZOsZ{cursor:pointer;}/*!sc*/
# .bhZOsZ::before{border-radius:var(--track-radius);background:rgba(0,0,0,0.5);top:1px;bottom:1px;left:1px;right:1px;}/*!sc*/
# .simplebar-hover .sc-1dw6i8r::before,.simplebar-mouse-entered .bhZOsZ::before,.simplebar-dragging .bhZOsZ::before{top:0;bottom:0;left:0;right:0;}/*!sc*/
# .simplebar-scrolling .sc-1dw6i8r::before,.simplebar-hover .bhZOsZ::before,.simplebar-mouse-entered .bhZOsZ::before,.simplebar-dragging .bhZOsZ::before{opacity:1;}/*!sc*/
# .bhZOsZ.simplebar-visible::before{opacity:1;}/*!sc*/
# data-styled.g31[id="sc-1dw6i8r"]{content:"bhZOsZ,"}/*!sc*/
# .ilfMLh{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}/*!sc*/
# data-styled.g106[id="sc-1iqzwcj-0"]{content:"ilfMLh,"}/*!sc*/
# .keePnH{position:relative;}/*!sc*/
# data-styled.g107[id="rlqnj2-0"]{content:"keePnH,"}/*!sc*/
# .juCHWK{visibility:hidden;pointer-events:none;}/*!sc*/
# data-styled.g108[id="rlqnj2-1"]{content:"juCHWK,"}/*!sc*/
# .irxtVB{position:absolute;left:0;top:0;right:0;bottom:0;height:100%;width:100%;}/*!sc*/
# data-styled.g109[id="rlqnj2-2"]{content:"irxtVB,"}/*!sc*/
# .eOQgZp{border-radius:50%;overflow:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g114[id="yj50et-0"]{content:"eOQgZp,"}/*!sc*/
# .emcbOS{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# .empKoK{background:#006ea5;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g115[id="yj50et-1"]{content:"emcbOS,empKoK,"}/*!sc*/
# .dwYqDL{display:block;border-radius:50%;object-fit:cover;}/*!sc*/
# data-styled.g116[id="yj50et-2"]{content:"dwYqDL,"}/*!sc*/
# .epbkjc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g121[id="euk31c-0"]{content:"epbkjc,"}/*!sc*/
# .ftveEB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g122[id="euk31c-1"]{content:"ftveEB,"}/*!sc*/
# .hkziuG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g123[id="euk31c-2"]{content:"hkziuG,"}/*!sc*/
# .iVGtVg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.5);}/*!sc*/
# .iVGtVg:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g124[id="euk31c-3"]{content:"iVGtVg,"}/*!sc*/
# .hBautw{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g125[id="euk31c-4"]{content:"hBautw,"}/*!sc*/
# .bBDMEV{background-color:#a3a3a3;color:#fff;font-size:12px;line-height:20px;padding:0 4px;border-radius:4px;margin-left:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g128[id="euk31c-7"]{content:"bBDMEV,"}/*!sc*/
# .bpKuNv{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .jpJQOT{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g133[id="jjui6k-0"]{content:"bpKuNv,jpJQOT,"}/*!sc*/
# .BVTPe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# .BVTPe .sc-husrwi{width:24px;height:24px;fill:#fff;}/*!sc*/
# data-styled.g134[id="jjui6k-1"]{content:"BVTPe,"}/*!sc*/
# .bpkyqV{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g135[id="sc-1ahzbiw-0"]{content:"bpkyqV,"}/*!sc*/
# .dyeXwg{display:block;height:100%;}/*!sc*/
# data-styled.g136[id="sc-139xjgq-0"]{content:"dyeXwg,"}/*!sc*/
# .fgYDOw{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g137[id="dqjqtp-0"]{content:"fgYDOw,"}/*!sc*/
# .dZxiDA{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g145[id="fdq12b-0"]{content:"dZxiDA,"}/*!sc*/
# .dhKHYI .sc-1plrgiz-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g147[id="lhzs50-0"]{content:"dhKHYI,"}/*!sc*/
# .epaurX{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g148[id="dz5d85-0"]{content:"epaurX,"}/*!sc*/
# .ibYNxL{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g149[id="dz5d85-1"]{content:"ibYNxL,"}/*!sc*/
# .ijkWTi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g150[id="dz5d85-2"]{content:"ijkWTi,"}/*!sc*/
# .fZCpwm{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g155[id="bxef95-0"]{content:"fZCpwm,"}/*!sc*/
# .iGGWNS{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g156[id="bxef95-1"]{content:"iGGWNS,"}/*!sc*/
# .fvZEcc{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g169[id="gthja3-1"]{content:"fvZEcc,"}/*!sc*/
# .jGtkKv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .jGtkKv:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g176[id="sc-11gkikh-0"]{content:"jGtkKv,"}/*!sc*/
# .croAom{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g227[id="cgoejl-0"]{content:"croAom,"}/*!sc*/
# .liVVKX{display:block;border-radius:50%;border:2px solid #fff;margin-left:-4px;box-sizing:content-box;}/*!sc*/
# .liVVKX:first-child{margin-left:0;}/*!sc*/
# data-styled.g228[id="cgoejl-1"]{content:"liVVKX,"}/*!sc*/
# .fZnlej{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# .fZnlej .cgoejl-1{width:16px;height:16px;}/*!sc*/
# data-styled.g229[id="cgoejl-2"]{content:"fZnlej,"}/*!sc*/
# .jMiYgp{padding-left:6px;}/*!sc*/
# data-styled.g230[id="cgoejl-3"]{content:"jMiYgp,"}/*!sc*/
# .dOWNhR{width:100%;}/*!sc*/
# data-styled.g238[id="okwoqf-0"]{content:"dOWNhR,"}/*!sc*/
# .frGBlJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin:0;border:1px solid rgba(0,0,0,0.15);border-radius:12px;background:#fff;width:100%;height:92px;overflow:hidden;}/*!sc*/
# data-styled.g239[id="sc-17aqgmq-0"]{content:"frGBlJ,"}/*!sc*/
# .jhIZYh{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns 0.5s;transition:grid-template-columns 0.5s;}/*!sc*/
# data-styled.g275[id="bvk29r-0"]{content:"jhIZYh,"}/*!sc*/
# .cXYfzh{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g276[id="bvk29r-1"]{content:"cXYfzh,"}/*!sc*/
# .glwZhP{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g277[id="bvk29r-2"]{content:"glwZhP,"}/*!sc*/
# .PZtuP{grid-column:mainRight / end;}/*!sc*/
# data-styled.g278[id="bvk29r-3"]{content:"PZtuP,"}/*!sc*/
# .gsZYxo{margin:0 12px;min-height:calc( 100vh - 68px );min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g279[id="sc-10tqbnq-0"]{content:"gsZYxo,"}/*!sc*/
# .kuiJhT{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g280[id="sc-10tqbnq-1"]{content:"kuiJhT,"}/*!sc*/
# .jTZxum{grid-area:thumb;overflow:hidden;border-radius:12px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g299[id="sc-2rneb0-0"]{content:"jTZxum,"}/*!sc*/
# .cDiqBT{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g300[id="uj732l-0"]{content:"cDiqBT,"}/*!sc*/
# .fFUtFn{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# .cjipAY{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g301[id="uj732l-1"]{content:"fFUtFn,cjipAY,"}/*!sc*/
# .eaMAYW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .eaMAYW:last-child{padding-right:0;}/*!sc*/
# .eaMAYW .sc-husrwi{width:20px;height:20px;margin-right:6px;}/*!sc*/
# .ghvDya{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .ghvDya:last-child{padding-right:0;}/*!sc*/
# .ghvDya .sc-husrwi{width:20px;height:20px;margin-right:6px;fill:#3397cf;}/*!sc*/
# data-styled.g302[id="uj732l-2"]{content:"eaMAYW,ghvDya,"}/*!sc*/
# .gFYeFH{position:relative;z-index:1;}/*!sc*/
# data-styled.g303[id="uj732l-4"]{content:"gFYeFH,"}/*!sc*/
# .bReysV{margin:0 60px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 0px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g304[id="tgn9uw-0"]{content:"bReysV,"}/*!sc*/
# .ceKcvN{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g305[id="tgn9uw-1"]{content:"ceKcvN,"}/*!sc*/
# .jWUdzO{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g306[id="tgn9uw-2"]{content:"jWUdzO,"}/*!sc*/
# .cUGTXH{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .cUGTXH::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g307[id="tgn9uw-3"]{content:"cUGTXH,"}/*!sc*/
# .jtaqbD{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g308[id="tgn9uw-4"]{content:"jtaqbD,"}/*!sc*/
# .cHyarR{font-size:14px;padding-left:4px;border-left:4px solid rgba(0,0,0,.15);color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g309[id="tgn9uw-5"]{content:"cHyarR,"}/*!sc*/
# .llxMbX{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .llxMbX vmfive-ad-unit{width:100%;}/*!sc*/
# data-styled.g318[id="sc-1x2g0l4-0"]{content:"llxMbX,"}/*!sc*/
# .kvivaM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g336[id="j38qb8-0"]{content:"kvivaM,"}/*!sc*/
# .coCrfJ{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g337[id="j38qb8-1"]{content:"coCrfJ,"}/*!sc*/
# .ZDttY{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .ZDttY >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g347[id="vnm9ni-0"]{content:"ZDttY,"}/*!sc*/
# .jdZdIW{position:relative;}/*!sc*/
# .jdZdIW::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g350[id="m2vgdk-0"]{content:"jdZdIW,"}/*!sc*/
# .hkUAph{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g384[id="sc-1bfxmuy-0"]{content:"hkUAph,"}/*!sc*/
# .iVjreC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:30px;height:30px;position:relative;}/*!sc*/
# .iVjreC .sc-husrwi{fill:#fff;width:24px;height:24px;}/*!sc*/
# data-styled.g385[id="sc-1bfxmuy-1"]{content:"iVjreC,"}/*!sc*/
# .dfameG{height:1px;}/*!sc*/
# data-styled.g648[id="sc-1ocsimk-0"]{content:"dfameG,"}/*!sc*/
# .buWRCP{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g660[id="sc-1wisey8-0"]{content:"buWRCP,"}/*!sc*/
# .bEkSbh{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;}/*!sc*/
# .bEkSbh img,.bEkSbh .sc-husrwi{display:block;width:24px;height:24px;fill:rgba(0,0,0,0.2);}/*!sc*/
# .bEkSbh:hover img,.bEkSbh:hover .sc-husrwi{fill:#ea5c5c;}/*!sc*/
# .eHUhbq{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;}/*!sc*/
# .eHUhbq img,.eHUhbq .sc-husrwi{display:block;width:24px;height:24px;fill:rgba(0,0,0,0.2);}/*!sc*/
# .eHUhbq:hover img,.eHUhbq:hover .sc-husrwi{fill:#3397cf;}/*!sc*/
# data-styled.g670[id="sc-17034tg-0"]{content:"bEkSbh,eHUhbq,"}/*!sc*/
# .bbqymi{border-radius:4px 4px 0 0;background-color:#fff;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g744[id="d4ydwz-0"]{content:"bbqymi,"}/*!sc*/
# .jLfDhx{background:#fff;}/*!sc*/
# data-styled.g746[id="sc-1db29sy-0"]{content:"jLfDhx,"}/*!sc*/
# .khkGZN{width:100%;}/*!sc*/
# data-styled.g861[id="sc-131a6oy-0"]{content:"khkGZN,"}/*!sc*/
# .eFKPDp{border-radius:12px;margin-top:8px;overflow:hidden;}/*!sc*/
# .zdsTu{border-radius:0px;margin-top:0px;overflow:hidden;}/*!sc*/
# data-styled.g862[id="sc-1k1o5vl-0"]{content:"eFKPDp,zdsTu,"}/*!sc*/
# .glqfqq{display:none;}/*!sc*/
# .glqvvE{display:grid;}/*!sc*/
# data-styled.g863[id="sc-1k1o5vl-1"]{content:"glqfqq,glqvvE,"}/*!sc*/
# .cywuvu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g864[id="sc-1k1o5vl-2"]{content:"cywuvu,"}/*!sc*/
# .fXkhnL{margin:0 60px;border-bottom:1px solid rgb(233,233,233);}/*!sc*/
# data-styled.g865[id="sc-1k1o5vl-3"]{content:"fXkhnL,"}/*!sc*/
# .KQVfH{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);margin-bottom:12px;}/*!sc*/
# data-styled.g866[id="sc-1byfryj-0"]{content:"KQVfH,"}/*!sc*/
# .iIZKzj{border-radius:12px;overflow:hidden;margin-top:8px;-webkit-mask-image:linear-gradient(black,white);}/*!sc*/
# data-styled.g867[id="sc-1byfryj-1"]{content:"iIZKzj,"}/*!sc*/
# .eAzWNg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g895[id="sc-1nqrhll-0"]{content:"eAzWNg,"}/*!sc*/
# .goKrVj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .goKrVj > *{height:100%;width:100%;}/*!sc*/
# data-styled.g896[id="sc-1nqrhll-1"]{content:"goKrVj,"}/*!sc*/
# .iQihnd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;}/*!sc*/
# data-styled.g898[id="sc-1iit2li-0"]{content:"iQihnd,"}/*!sc*/
# .hOwDyB{position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;border-bottom:1px solid rgba(0,0,0,0.15);border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g899[id="sc-1iit2li-1"]{content:"hOwDyB,"}/*!sc*/
# .jOgXbG{width:100%;z-index:1;}/*!sc*/
# data-styled.g905[id="sc-1iit2li-7"]{content:"jOgXbG,"}/*!sc*/
# .cpFflv{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g906[id="sc-1kb03aj-0"]{content:"cpFflv,"}/*!sc*/
#   </style>
#  </head>
#  <body>
#   <div id="__next">
#    <div class="bxef95-0 fZCpwm">
#     <div class="dz5d85-0 epaurX">
#      <div class="dz5d85-1 ibYNxL">
#       <a class="dqjqtp-0 fgYDOw" href="/f" title="Dcard">
#        <img alt="Dcard" class="sc-139xjgq-0 dyeXwg" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/>
#       </a>
#       <div class="bxef95-1 iGGWNS">
#        <div class="dj0ioy-0 gVUpsb">
#         <form action="">
#          <input aria-label="搜尋" class="dj0ioy-2 fysraG" name="query" placeholder="搜尋" type="search" value=""/>
#          <button class="dj0ioy-3 kacUhU" disabled="" title="搜尋" type="submit">
#           <svg aria-hidden="true" class="sc-husrwi dvqhOE dj0ioy-7 dbNcOQ" focusable="false" height="20" role="img" style="fill:#fff" viewbox="0 0 28 28" width="20">
#            <path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z">
#            </path>
#           </svg>
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <div class="dz5d85-2 ijkWTi" role="navigation">
#       <a class="jjui6k-0 bpKuNv sc-1ahzbiw-0 bpkyqV" href="/service/_auth/authorize?redirect=%2Fservice%2Fsso%2Fcallback%3Fredirect%3D%252Ff&amp;ui_locales=zh-TW&amp;prompt=login&amp;product=Dcard&amp;region=TW" role="button">
#        <span class="jjui6k-1 BVTPe">
#         註冊 / 登入
#        </span>
#       </a>
#       <div class="fdq12b-0 dZxiDA">
#        <a class="jjui6k-0 jpJQOT" role="button" title="更多">
#         <span class="jjui6k-1 BVTPe">
#          <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#           <path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="bvk29r-0 jhIZYh">
#     <div class="bvk29r-1 cXYfzh">
#      <div class="sc-1bfxmuy-0 hkUAph">
#       <a href="/forum/all">
#        <div class="sc-11gkikh-0 jGtkKv">
#         <div class="sc-1bfxmuy-1 iVjreC">
#          <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#           <path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum">
#           </path>
#          </svg>
#         </div>
#         <div class="gthja3-1 fvZEcc">
#          所有看板
#         </div>
#        </div>
#       </a>
#       <a href="/forum/popular">
#        <div class="sc-11gkikh-0 jGtkKv">
#         <div class="sc-1bfxmuy-1 iVjreC">
#          <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#           <path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot">
#           </path>
#          </svg>
#         </div>
#         <div class="gthja3-1 fvZEcc">
#          即時熱門看板
#         </div>
#        </div>
#       </a>
#       <a href="/goods">
#        <div class="sc-11gkikh-0 jGtkKv">
#         <div class="sc-1bfxmuy-1 iVjreC">
#          <svg aria-hidden="true" class="sc-husrwi dvqhOE m2vgdk-0 jdZdIW" focusable="false" height="24" role="img" style="fill:#fff" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z">
#           </path>
#           <path d="M0 0h24v24H0z" fill="none">
#           </path>
#          </svg>
#         </div>
#         <div class="gthja3-1 fvZEcc">
#          好物研究室
#         </div>
#        </div>
#       </a>
#       <div class="sc-qz0f8b idVSLh">
#        <div class="simplebar-wrapper">
#         <div class="simplebar-height-auto-observer-wrapper">
#          <div class="simplebar-height-auto-observer">
#          </div>
#         </div>
#         <div class="simplebar-mask">
#          <div class="simplebar-offset">
#           <div class="simplebar-content-wrapper">
#            <div class="simplebar-content">
#             <span>
#             </span>
#             <span>
#             </span>
#             <span>
#             </span>
#             <span>
#             </span>
#             <span>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="simplebar-placeholder">
#         </div>
#        </div>
#        <div class="sc-bdvvaa eRQARU simplebar-track simplebar-horizontal">
#         <div class="sc-1dw6i8r bhZOsZ simplebar-scrollbar">
#         </div>
#        </div>
#        <div class="sc-bdvvaa eRQARU simplebar-track simplebar-vertical">
#         <div class="sc-1dw6i8r bhZOsZ simplebar-scrollbar">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="bvk29r-2 glwZhP">
#      <div class="sc-10tqbnq-0 gsZYxo" role="main">
#       <div class="sc-10tqbnq-1 kuiJhT">
#        <div class="d4ydwz-0 bbqymi">
#         <div class="sc-1kb03aj-0 cpFflv">
#          <div class="sc-1iit2li-0 sc-1iit2li-1 iQihnd hOwDyB">
#           <div class="sc-1iit2li-7 jOgXbG">
#            <div class="sc-1nqrhll-0 eAzWNg">
#             <div class="sc-1nqrhll-1 goKrVj">
#              <div class="pkcmwm-0 dAVCLF">
#               <a class="pkcmwm-1 dzaAJe" href="/f" size="1">
#                熱門
#               </a>
#               <a class="pkcmwm-1 jlRzxR" href="/f?latest=true" size="1">
#                最新
#               </a>
#               <a class="pkcmwm-1 jlRzxR" href="/f?pessoal=true" size="1">
#                追蹤
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="sc-1wisey8-0 buWRCP">
#           <div class="sc-1db29sy-0 jLfDhx">
#            <div style="padding-top:0;padding-bottom:0">
#             <div data-index="0">
#             </div>
#             <div data-index="1">
#              <article class="tgn9uw-0 bReysV" data-post-list-viewed-cell-no="2" role="article">
#               <div class="tgn9uw-1 ceKcvN">
#                <div class="euk31c-0 epbkjc">
#                 <div class="euk31c-4 hBautw">
#                  <div class="yj50et-0 eOQgZp euk31c-5 etmCKd">
#                   <svg class="sc-husrwi dvqhOE sc-1airdzr-0 eYzQsU" focusable="false" height="16" style="fill:#006aa6" viewbox="0 0 100 100" width="16">
#                    <title>
#                     官方
#                    </title>
#                    <path d="M100 50A50 50 0 110 50a50 50 0 01100 0">
#                    </path>
#                    <g fill="#FFF">
#                     <path d="M61 43.7a4.9 4.9 0 00-5 5c0 2.6 2.3 4.8 5 4.8s4.9-2.2 4.9-4.9-2.2-4.9-5-4.9">
#                     </path>
#                     <path d="M69.7 55.8l-.1 1.8a3.9 3.9 0 01-3.2.6c-1.6-.5-3.1-1.4-4.3-2.5l-4.1 4c2.5 2.5 5.7 4.2 9.4 4.7-3 5.3-8.8 9-15.3 9H34.5V49.5a44 44 0 0029.4-17.2c1.5 1 2.8 2.2 3.7 3.5 1.3 2.5 2 5.3 2 8.3v11.6zM52 20.8H28.6v58.4h23.5c13 0 23.4-10.5 23.4-23.4V44.2a23.4 23.4 0 00-23.4-23.4z">
#                     </path>
#                    </g>
#                    <path d="M20.8 20.8h58.3v58.3H20.8z" fill="none">
#                    </path>
#                   </svg>
#                  </div>
#                 </div>
#                 <div class="euk31c-1 ftveEB">
#                  <div class="euk31c-2 hkziuG">
#                   <div class="euk31c-3 iVGtVg">
#                    工作
#                   </div>
#                   <div class="euk31c-3 iVGtVg">
#                    練習生小助教
#                   </div>
#                  </div>
#                  <div class="euk31c-7 bBDMEV" style="background-color:#a3a3a3">
#                   置頂
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="tgn9uw-2 jWUdzO">
#                <a class="tgn9uw-3 cUGTXH" href="/f/job/p/236285229">
#                 <span>
#                  全站募集📢 #練習生Lv2 遇過最荒謬的職場經驗 🤖 等你來+1
#                 </span>
#                </a>
#               </h2>
#               <div class="uj732l-0 cDiqBT">
#                <div class="tgn9uw-4 jtaqbD">
#                 <span>
#                  嘿！練習生們趕快來迎接 Lv2 挑戰！，這週的主題是 🤖  遇過最荒謬的職場經驗 🤖，可以分享，防疫在家工作的荒謬事，你遇過的奇葩同事或主管，自己工作或面試發生過的奇葩經驗，奇葩工作習慣，大學打工、兼
#                 </span>
#                </div>
#               </div>
#               <div class="uj732l-1 fFUtFn">
#                <div class="uj732l-2 eaMAYW">
#                 <div class="cgoejl-0 croAom">
#                  <div class="cgoejl-2 fZnlej">
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" style="z-index:2" title="愛心"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/2484e51a-2cdc-4f0e-a4ea-8d80b4589762/orig.png" style="z-index:1" title="驚訝"/>
#                  </div>
#                  <div class="cgoejl-3 jMiYgp">
#                   307
#                  </div>
#                 </div>
#                </div>
#                <div class="uj732l-2 eaMAYW">
#                 <div class="uj732l-2 ghvDya">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M1.3330000000000002 12a10.667 10.667 0 1021.334 0 10.667 10.667 0 10-21.334 0zM15.5 6.5h-7A3.5 3.5 0 005 10v3.5A3.5 3.5 0 008.5 17H9v1.369a.75.75 0 001.238.57L12.5 17h3a3.5 3.5 0 003.5-3.5V10a3.5 3.5 0 00-3.5-3.5z" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                  <span>
#                   7
#                  </span>
#                 </div>
#                </div>
#                <div class="uj732l-4 gFYeFH">
#                 <div class="uj732l-2 eaMAYW">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                   </path>
#                  </svg>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <img alt="" class="sc-2rneb0-0 jTZxum tgn9uw-7 esWtrP" height="84px" loading="lazy" referrerpolicy="no-referrer" src="https://imgur.dcard.tw/0QkUXaub.jpg" width="84px"/>
#              </article>
#             </div>
#             <div data-index="2">
#              <article class="tgn9uw-0 bReysV" data-post-list-viewed-cell-no="3" role="article">
#               <div class="tgn9uw-1 ceKcvN">
#                <div class="euk31c-0 epbkjc">
#                 <div class="euk31c-4 hBautw">
#                  <img alt="" class="yj50et-2 dwYqDL euk31c-5 etmCKd" height="16" loading="lazy" src="https://megapx-assets.dcard.tw/images/e7b08b5b-43b1-4994-adb0-bb22098560f7/orig.png" width="16"/>
#                 </div>
#                 <div class="euk31c-1 ftveEB">
#                  <div class="euk31c-2 hkziuG">
#                   <div class="euk31c-3 iVGtVg">
#                    手搖
#                   </div>
#                   <div class="euk31c-3 iVGtVg">
#                    男孩與貓
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="tgn9uw-2 jWUdzO">
#                <a class="tgn9uw-3 cUGTXH" href="/f/boba/p/236276014">
#                 <span>
#                  最討厭的三大奧客類型🙄️
#                 </span>
#                </a>
#               </h2>
#               <div class="uj732l-0 cDiqBT">
#                <div class="tgn9uw-4 jtaqbD">
#                 <span>
#                  點完餐才拿錢包出來慢慢掏，或是講話小聲到只有鬼才能聽到，這些真的都是小case。—————————，第三名：無聲勝有聲。「您好，今天喝什麼呢️？」看菜單的奧客，「⋯」「還是想喝什麼類型，可以幫你推薦哦️」
#                 </span>
#                </div>
#               </div>
#               <div class="uj732l-1 fFUtFn">
#                <div class="uj732l-2 eaMAYW">
#                 <div class="cgoejl-0 croAom">
#                  <div class="cgoejl-2 fZnlej">
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" style="z-index:3" title="愛心"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/9a7cc9af-9f81-43ea-8d9b-968a6441ae51/orig.png" style="z-index:2" title="哈哈"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/2484e51a-2cdc-4f0e-a4ea-8d80b4589762/orig.png" style="z-index:1" title="驚訝"/>
#                  </div>
#                  <div class="cgoejl-3 jMiYgp">
#                   3564
#                  </div>
#                 </div>
#                </div>
#                <div class="uj732l-2 eaMAYW">
#                 <div class="uj732l-2 ghvDya">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M1.3330000000000002 12a10.667 10.667 0 1021.334 0 10.667 10.667 0 10-21.334 0zM15.5 6.5h-7A3.5 3.5 0 005 10v3.5A3.5 3.5 0 008.5 17H9v1.369a.75.75 0 001.238.57L12.5 17h3a3.5 3.5 0 003.5-3.5V10a3.5 3.5 0 00-3.5-3.5z" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                  <span>
#                   213
#                  </span>
#                 </div>
#                </div>
#                <div class="uj732l-4 gFYeFH">
#                 <div class="uj732l-2 eaMAYW">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                   </path>
#                  </svg>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#             <div data-index="3">
#              <article class="tgn9uw-0 bReysV" data-post-list-viewed-cell-no="4" role="article">
#               <div class="tgn9uw-1 ceKcvN">
#                <div class="euk31c-0 epbkjc">
#                 <div class="euk31c-4 hBautw">
#                  <div aria-label="mj94819" class="yj50et-1 emcbOS euk31c-5 etmCKd" role="img" size="16">
#                   M
#                  </div>
#                 </div>
#                 <div class="euk31c-1 ftveEB">
#                  <div class="euk31c-2 hkziuG">
#                   <div class="euk31c-3 iVGtVg">
#                    感情
#                   </div>
#                   <div class="euk31c-3 iVGtVg">
#                    171高個女森
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="tgn9uw-2 jWUdzO">
# ...
#                 <div class="cgoejl-0 croAom">
#                  <div class="cgoejl-2 fZnlej">
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" style="z-index:3" title="愛心"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/9a7cc9af-9f81-43ea-8d9b-968a6441ae51/orig.png" style="z-index:2" title="哈哈"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/039a093e-93ec-476c-976c-4a53b9b6d11c/orig.png" style="z-index:1" title="嗚嗚"/>
#                  </div>
#                  <div class="cgoejl-3 jMiYgp">
#                   580
#                  </div>
#                 </div>
#                </div>
#                <div class="uj732l-2 eaMAYW">
#                 <div class="uj732l-2 ghvDya">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M1.3330000000000002 12a10.667 10.667 0 1021.334 0 10.667 10.667 0 10-21.334 0zM15.5 6.5h-7A3.5 3.5 0 005 10v3.5A3.5 3.5 0 008.5 17H9v1.369a.75.75 0 001.238.57L12.5 17h3a3.5 3.5 0 003.5-3.5V10a3.5 3.5 0 00-3.5-3.5z" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                  <span>
#                   43
#                  </span>
#                 </div>
#                </div>
#                <div class="uj732l-4 gFYeFH">
#                 <div class="uj732l-2 eaMAYW">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                   </path>
#                  </svg>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <img alt="" class="sc-2rneb0-0 jTZxum tgn9uw-7 esWtrP" height="84px" loading="lazy" referrerpolicy="no-referrer" src="https://imgur.dcard.tw/VvnkyVUb.jpg" width="84px"/>
#              </article>
#             </div>
#             <div data-index="37">
#              <article class="tgn9uw-0 bReysV" data-post-list-viewed-cell-no="38" role="article">
#               <div class="tgn9uw-1 ceKcvN">
#                <div class="euk31c-0 epbkjc">
#                 <div class="euk31c-4 hBautw">
#                  <div aria-label="frankfurt" class="yj50et-1 empKoK euk31c-5 etmCKd" role="img" size="16">
#                   F
#                  </div>
#                 </div>
#                 <div class="euk31c-1 ftveEB">
#                  <div class="euk31c-2 hkziuG">
#                   <div class="euk31c-3 iVGtVg">
#                    理財
#                   </div>
#                   <div class="euk31c-3 iVGtVg">
#                    德意志
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <h2 class="tgn9uw-2 jWUdzO">
#                <a class="tgn9uw-3 cUGTXH" href="/f/money/p/236274544">
#                 <span>
#                  終於達到10桶金
#                 </span>
#                </a>
#               </h2>
#               <div class="uj732l-0 cDiqBT">
#                <div class="tgn9uw-4 jtaqbD">
#                 <span>
#                  去年疫情後蠻積極的操作股票，都採保守的投資研究。傳產石化，民生紡織，內需食品，保全等，小量的etf（0056），陸續賺了約100萬。這2~3周終於把剩餘持股出清，可以停歇一下。今天網銀入帳終於看到小小
#                 </span>
#                </div>
#               </div>
#               <div class="uj732l-1 fFUtFn">
#                <div class="uj732l-2 eaMAYW">
#                 <div class="cgoejl-0 croAom">
#                  <div class="cgoejl-2 fZnlej">
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" style="z-index:3" title="愛心"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/8ba704c3-2661-4f21-b874-fb28ee5e22ef/orig.png" style="z-index:2" title="跪"/>
#                   <img class="cgoejl-1 liVVKX" src="https://megapx-assets.dcard.tw/images/9a7cc9af-9f81-43ea-8d9b-968a6441ae51/orig.png" style="z-index:1" title="哈哈"/>
#                  </div>
#                  <div class="cgoejl-3 jMiYgp">
#                   567
#                  </div>
#                 </div>
#                </div>
#                <div class="uj732l-2 eaMAYW">
#                 <div class="uj732l-2 ghvDya">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M1.3330000000000002 12a10.667 10.667 0 1021.334 0 10.667 10.667 0 10-21.334 0zM15.5 6.5h-7A3.5 3.5 0 005 10v3.5A3.5 3.5 0 008.5 17H9v1.369a.75.75 0 001.238.57L12.5 17h3a3.5 3.5 0 003.5-3.5V10a3.5 3.5 0 00-3.5-3.5z" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                  <span>
#                   141
#                  </span>
#                 </div>
#                </div>
#                <div class="uj732l-4 gFYeFH">
#                 <div class="uj732l-2 eaMAYW">
#                  <svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24">
#                   <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                   </path>
#                  </svg>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <img alt="" class="sc-2rneb0-0 jTZxum tgn9uw-7 esWtrP" height="84px" loading="lazy" referrerpolicy="no-referrer" src="https://imgur.dcard.tw/CNugcr8b.jpg" width="84px"/>
#              </article>
#             </div>
#            </div>
#            <div style="display:block">
#             <div class="sc-1ocsimk-0 dfameG">
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="bvk29r-3 PZtuP">
#      <aside class="vnm9ni-0 ZDttY">
#       <div class="sc-1x2g0l4-0 llxMbX" style="min-height:250px">
#        <div id="div-gpt-ad-1458631742813-0" style="height:250px;width:300px">
#        </div>
#       </div>
#       <div class="sc-1x2g0l4-0 llxMbX" style="min-height:250px">
#        <div id="div-gpt-ad-1466065536619-0" style="height:250px;width:300px">
#        </div>
#       </div>
#       <div class="sc-1x2g0l4-0 llxMbX" style="min-height:600px">
#        <div id="div-gpt-ad-1582095045953-0" style="height:600px;width:300px">
#        </div>
#       </div>
#       <div class="sc-1x2g0l4-0 llxMbX" style="min-height:250px">
#        <div id="div-gpt-ad-1582095257338-0" style="height:250px;width:300px">
#        </div>
#       </div>
#       <div class="sc-1x2g0l4-0 llxMbX" style="min-height:600px">
#        <div id="div-gpt-ad-1458631598292-0" style="height:600px;width:300px">
#        </div>
#       </div>
#       <div class="j38qb8-0 kvivaM">
#        <a class="j38qb8-1 coCrfJ" href="/terms" target="_blank">
#         服務條款
#        </a>
#        <a class="j38qb8-1 coCrfJ" href="https://about.dcard.tw/faq" target="_blank">
#         常見問題
#        </a>
#        <a class="j38qb8-1 coCrfJ" href="/brand/dcard_brand_guidelines.pdf" target="_blank">
#         品牌識別
#        </a>
#        <a class="j38qb8-1 coCrfJ" href="https://join.dcard.today" target="_blank">
#         徵才
#        </a>
#        <a class="j38qb8-1 coCrfJ" href="https://about.dcard.tw/business" target="_blank">
#         商業合作
#        </a>
#       </div>
#      </aside>
#     </div>
#    </div>
#    <noscript>
#     <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=33827916"/>
#    </noscript>
#    <noscript>
#     <img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=gj89j1a8Dy000J" style="display:none" width="1"/>
#    </noscript>
#    <noscript>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TWLTW4M" style="display:none;visibility:hidden" width="0">
#     </iframe>
#    </noscript>
#   </div>
#   <script id="__INTL_REGISTRY__" type="application/json">
#    {"meta.dcard_app.description_format":"廣受年輕人喜愛的 {product} 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！","search.main.action":"搜尋","form_validation.is_required.message":"此欄位為必填。","signup.login_or_signup.action":"註冊 / 登入","settings.end_user_agreement.option":"服務條款","general.free_to_download.description":"免費下載 App","settings.main.title":"設定","member.logout.action":"登出","settings.faq.option":"常見問題","general.report_problem.description":"回報問題","general.brand_identification.description":"品牌識別","general.hiring.description":"徵才","general.business.description":"商業合作","general.more.action":"更多","forum_list.all_title.option":"所有看板","forum_list.realtime_popular.title":"即時熱門看板","ec.short.title":"好物研究室","forum_list.moderator.title":"板主相關","forum_list.favorites.title":"我的最愛","forum_list.selected.title_format":"{product} 精選看板","forum.all.title":"全部","collection.put.action":"收藏","time_format.less_than_one_day.description_format":"{hours} 小時前","post.official.description":"官方","time_format.less_than_seven_day.description_format":"{days} 天前","post.anonymous.description":"匿名","member.gender_female.option":"女","reaction.info.title":"心情","member.gender_male.option":"男","forum.welcome.message_format":"歡迎來到{forumName}板。"}
#   </script>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"envelope":{"pager":"legacy","options":{"paginationOptions":{"forumAlias":"all"},"isPessoalButNotLoggedin":false,"sourceKey":"hot"}},"forumAlias":"all","tabQuery":{},"tabs":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy","nameMessage":{"type":"string","message":"熱門"},"isHome":false},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy","nameMessage":{"type":"string","message":"最新"},"isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","nameMessage":{"type":"string","message":"追蹤"},"isHome":false}],"query":{},"kbkPosts":[]}},"isLogin":false,"isMobile":false,"initialState":{"adItem":{"data":{"558bae61-cb3c-4604-b281-473b6bf1047d":[],"f0fc1371-7da6-472b-be89-6392f8869ea4":[],"2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[],"a0d23a73-66bb-4704-af18-286c6b0292f9":[],"63463c6f-e951-4d18-b559-6e6c5e629ec3":[],"e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[],"d1555d99-c344-499a-b0ee-fadfa2f2b216":[],"adUnitId=558bae61-cb3c-4604-b281-473b6bf1047d":[{"provider":"google","id":"/146730420/Desktop-Right-Top"}],"adUnitId=f0fc1371-7da6-472b-be89-6392f8869ea4":[{"provider":"google","id":"/146730420/Desktop-Beyond-FB"}],"adUnitId=2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[{"provider":"google","id":"/146730420/Desktop-Right3"}],"adUnitId=a0d23a73-66bb-4704-af18-286c6b0292f9":[{"provider":"google","id":"/146730420/Desktop-Right4"}],"adUnitId=63463c6f-e951-4d18-b559-6e6c5e629ec3":[{"provider":"google","id":"/146730420/Desktop-RightBottom-Bottom"}],"adUnitId=e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[{"provider":"google","id":"/146730420/Desktop-Article-Bottom"}],"adUnitId=d1555d99-c344-499a-b0ee-fadfa2f2b216":[{"provider":"google","id":"/146730420/Desktop-Comments"}],"adUnitId=e4d31040-b6b8-4479-9585-a28bd1c16832":[{"provider":"google","id":"/146730420/Mobile-Web-Screen-Top"}],"adUnitId=0c24cee5-97e0-486b-9dc1-b7d36bea93cb":[{"provider":"google","id":"/146730420/Mobile-Web-Article-End"}],"adUnitId=49317a19-f96f-42df-9dee-76bf1d62b6f9":[{"provider":"google","id":"/146730420/Mweb-Popular-Comments"}],"adUnitId=b29a047c-6238-449a-8355-2b5651ebe5b1":[{"provider":"google","id":"/146730420/Mweb-Comments"}],"adUnitId=88647537-2142-4839-88d4-780a6b7bf0e4":[{"provider":"google","id":"/146730420/Mobile-Web-Screen-Bottom"}],"adUnitId=63034007-a933-46ae-81cc-a9dce1a2552d":[{"provider":"google","id":"/146730420/Dtto-Desktop-Right-1st"}],"adUnitId=54cf0302-f980-4dd4-8c7c-2ff9f35814e1":[{"provider":"google","id":"/146730420/Dtto-Desktop-Right-2nd"}],"adUnitId=ee599045-c028-478a-9a86-72ea8360116e":[{"provider":"google","id":"/146730420/Dtto-Desktop-Right-3rd"}],"adUnitId=765edf71-161b-4156-9cf5-09a9bbe761b7":[{"provider":"google","id":"/146730420/Dtto-Mobile-Post-Bottom"}],"adUnitId=25bbf134-6c3c-4eac-8e00-0f922cff0434":[{"provider":"google","id":"/146730420/Desktop-1x1-Custom-1"}]},"error":null,"loading":false,"fetched":true},"adMessage":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}}},"adUnit":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"app":{"loading":false,"fetched":false,"data":{"product":"Dcard","isLogin":false,"isMobile":false,"isWebView":false,"ipCountry":"TW","locale":"zh-TW","supportedLanguages":["zh-TW"],"isFirstLoad":true,"issuerURL":"https://id.dcard.tw"}},"auth":{"socialLogin":{},"appleLogin":{}},"banner":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}}},"bookmark":{"loading":false,"fetched":false,"data":[]},"campaignSite":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}}},"channel":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"next ...
#   </script>
#   <script nomodule="" src="/_next/static/chunks/polyfills-ce2b19768abcde8ef682.js">
#   </script>
#   <script async="" src="/_next/static/chunks/9947.fb9060f9ed04fb2629cf.js">
#   </script>
#   <script async="" src="/_next/static/chunks/7100-7b499aeb928a9be4c3b2.js">
#   </script>
#   <script async="" src="/_next/static/chunks/1700.78fe7a6548a3b8233069.js">
#   </script>
#   <script async="" src="/_next/static/chunks/3555.58ca4dfa69b8a6ae79ba.js">
#   </script>
#   <script async="" src="/_next/static/chunks/8113.2144ecfdce71ccb41a23.js">
#   </script>
#   <script async="" src="/_next/static/chunks/1243.e7924db11cc0d5186be6.js">
#   </script>
#   <script async="" src="/_next/static/chunks/5835.1e8eb340807aeda3010a.js">
#   </script>
#   <script async="" src="/_next/static/chunks/3128.9da6ff9ebb87e7cec89b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/5723.acef286ce256a481df08.js">
#   </script>
#   <script async="" src="/_next/static/chunks/webpack-b633320a3c54f0b22c27.js">
#   </script>
#   <script async="" src="/_next/static/chunks/framework-56dc96a11889c53d8326.js">
#   </script>
#   <script async="" src="/_next/static/chunks/main-67488740558d7ef5d8cf.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/_app-6a9c10df246259e5038f.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons-01bb11fe342ffe07589b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/3021-15ce5b0cbf5ba2feadf9.js">
#   </script>
#   <script async="" src="/_next/static/chunks/2931-a7c0e4aebad7fef770b1.js">
#   </script>
#   <script async="" src="/_next/static/chunks/8096-27196a1723934def68ec.js">
#   </script>
#   <script async="" src="/_next/static/chunks/8455-2f2b6c6d411b39f5915c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/5313-c53007ced109ee5f330d.js">
#   </script>
#   <script async="" src="/_next/static/chunks/1623-64149042125b337fb0c2.js">
#   </script>
#   <script async="" src="/_next/static/chunks/7056-5fa799a911f2474cf143.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6991-a27bd903d14e2050dde3.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6473-6c9e9b3cdc4f4603ee03.js">
#   </script>
#   <script async="" src="/_next/static/chunks/8538-e16e7ce3c889c466f92b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/7570-aea065b5935a0f692ea2.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/forum-a9b8fc7def4f74ca9837.js">
#   </script>
#   <script async="" src="/_next/static/9166dc0212410943276172de3d9686174ee1f92f/_buildManifest.js">
#   </script>
#   <script async="" src="/_next/static/9166dc0212410943276172de3d9686174ee1f92f/_ssgManifest.js">
#   </script>
#  </body>
# </html>

# %%
from grab import Grab
g = Grab()
resp = g.go('https://google.com')
resp.body

from pyquery import PyQuery as pq
doc = pq(resp.body)
title = doc('title')
print(type(title), title.text())
