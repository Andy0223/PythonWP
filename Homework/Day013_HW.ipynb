# %% [markdown]
# ## 作業目標
# ### 根據範例 ，完成以下問題：
#
# ① 印出最新文章的「作者」「標題」「時間」
#
# ② 印出第一頁所有文章的「作者」「標題」「時間」
#
# ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print("標題："+d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間: ' + r.find_all(class_='article-meta-value')[-1].text)
        print()
    except:
        continue
# Out:
# 標題：[花邊] Morris：我們下賽季會讓可愛留下來的，
# 作者: arod1414 (Kawhi Leonard頭號粉絲)
# 時間: Thu Jul  1 20:54:27 2021
#
# 標題：(本文已被刪除) [jeff567t]
# 標題：[情報] 明日裁判名單
# 作者: aaagun (A槍大叔)
# 時間: Thu Jul  1 21:30:21 2021
#
# 標題：[討論] 各隊隊史冠軍次數
# 作者: hydeeric2002 (大頭)
# 時間: Thu Jul  1 21:44:16 2021
#
# 標題：Re: [討論] 快艇當年交易CP3算正確嗎？
# 作者: TheoEpstein (Red Sox→Cubs→？)
# 時間: Thu Jul  1 22:31:11 2021
#
# 標題：[情報] 獨行俠和熱火計劃對可愛展開猛烈追求
# 作者: adam7148 (Adam)
# 時間: Thu Jul  1 23:19:56 2021
#
# 標題：[討論] 今年季後賽開打前的湖人是不是被捧太高了
# 作者: afsmart (人之初，性本散)
# 時間: Thu Jul  1 23:38:06 2021
#
# 標題：[情報] 一些聯盟高管想知道Kawhi是否希望快艇交
# 作者: WIGGINS22 (楓葉國佐敦)
# 時間: Thu Jul  1 23:39:19 2021
#
# 標題：[討論]到底為什麼西門會是壯元??
# 作者: b9606022 (虛無飄渺)
# 時間: Thu Jul  1 23:46:24 2021
#
# 標題：[新聞] 柯瑞轉發林書豪推文 讚嘆CP3沒放棄
# 作者: pmdrt (=紅色民進黨 綠色共產黨=)
# 時間: Fri Jul  2 00:00:45 2021
#
# 標題：[情報] CP3是有進冠軍戰中場數第二長的球員
# 作者: XperiaZ6C (索尼)
# 時間: Fri Jul  2 00:19:06 2021
#
# 標題：[情報] 有五位NBA高管均認為可愛會留在快艇，與
# 作者: jeff567t (jeff567t)
# 時間: Fri Jul  2 00:25:39 2021
#
# 標題：[情報] 美國東奧靶子隊名單
# 作者: Wall62 ()
# 時間: Fri Jul  2 01:06:35 2021
#
# 標題：Re: [討論] 請問寄生迷現在支持哪一隊奪冠?
# 作者: s2081332 (noname)
# 時間: Fri Jul  2 01:30:46 2021
#
# 標題：[情報] 字母哥今天不打
# 作者: dragon803 (好想去露營啊~)
# 時間: Fri Jul  2 01:32:32 2021
#
# 標題：[花邊] 公鹿噩耗？波許以過來人經歷分析：字母
# 作者: XperiaZ6C (索尼)
# 時間: Fri Jul  2 01:47:08 2021
#
# 標題：[討論]  太陽要是奪冠 484要歸功於醫龍團隊？
# 作者: Preach (溫哥華八弟)
# 時間: Fri Jul  2 02:11:32 2021
#
# 標題：Re: [討論] 快艇當年交易CP3算正確嗎？
# 作者: RoseC (東羅)
# 時間: Fri Jul  2 02:37:29 2021
#
# 標題：[情報] Playoffs Schedule 20–21
# 作者: laptic (靜夜聖林彼岸花)
# 時間: Wed May 19 00:35:47 2021
#
# 標題：[情報] 2020-21 NBA Playoffs (Next：07/02 老公 G5)
# 作者: laptic (靜夜聖林彼岸花)
# 時間: Mon May 17 12:01:32 2021
#
# 標題：[公告] 板規v7.7
# 標題：[公告] 有獎徵求進板畫面 總獎金70000P
# 作者: Induction (愛人愛己)
# 時間: Wed Jun 23 06:46:54 2021
#
# 標題：[公告] 崩潰條款與引戰條款修正投票上線
# 作者: Induction (愛人愛己)
# 時間: Thu Jun 24 18:35:16 2021

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index1.html' #index1 是最舊的
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print("標題："+d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間: ' + r.find_all(class_='article-meta-value')[-1].text)
        print()
    except:
        continue
# Out:
# 標題：Re: [問題] 有關於搖擺的定義
# 作者: vfquest (大勝利！)
# 時間: Thu Jul 15 07:30:57 2004
#
# 標題：我看活塞
# 作者: Price (Price)
# 時間: Fri Jul 16 23:42:01 2004
#
# 標題：[轉錄] 活塞簽下 Antonio McDyess
# 作者: yushi (瓶子)
# 時間: Sat Jul 17 07:00:03 2004
#
# 標題：[轉錄]不被注意的交易
# 作者: yushi (瓶子)
# 時間: Sun Jul 18 21:10:34 2004
#
# 標題：Re: [影片]Ray Allen Mix
# 作者: sunnyside (藏心無忌)
# 時間: Thu Jul 22 02:05:03 2004
#
# 標題：Re: [問題] 請問坎普的球迷
# 作者: yushi (瓶子)
# 時間: Thu Jul 22 01:48:31 2004
#
# 標題：[話題球隊] 7/23-7/29 明尼蘇達灰狼
# 作者: yushi (瓶子)
# 時間: Fri Jul 23 03:44:02 2004
#
# 標題：KG 的 MVP 之旅
# 作者: JustCold (應無所住而生其心)
# 時間: Fri Jul 23 10:42:35 2004
#
# 標題：[心得]灰狼的歷年選秀
# 作者: aibakoji (洗版魔人)
# 時間: Fri Jul 23 18:50:01 2004
#
# 標題：有關灰狼的幾個網站
# 作者: jerod (只要妳的一句話)
# 時間: Sat Jul 24 00:52:23 2004
#
# 標題：[古董文章] 灰狼 GM Kevin McHale 傳
# 作者: DLowe (我的情婦叫丹丹)
# 時間: Sat Jul 24 13:33:40 2004
#
# 標題：[轉錄][我愛灰狼]我的灰狼史
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:28:50 2004
#
# 標題：[轉錄][我愛灰狼]不再孤獨
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:28:58 2004
#
# 標題：[轉錄][我愛灰狼]灰狼愛我
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:29:08 2004
#
# 標題：[轉錄][我愛灰狼]我的偶像：Kevin Garnett
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:29:22 2004
#
# 標題：[轉錄]Kevin Garnett: Passion Play (VI)
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:35:58 2004
#
# 標題：[轉錄]Kevin Garnett: Passion Play (VII)
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:36:06 2004
#
# 標題：[轉錄]Kevin Garnett: Passion Play (VIII)
# 作者: shanyaochung (還我小鳥!!)
# 時間: Sat Jul 24 18:36:12 2004
#
# 標題：[古董文]NBA隊名由來
# 作者: geminiman (老爹)
# 時間: Fri Jul 30 03:23:38 2004
#
# 標題：[話題球隊] 7/31-8/6 費城七六人
# 作者: yushi (瓶子)
# 時間: Sat Jul 31 14:35:52 2004

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index1.html' #index1 是最舊的
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print("標題："+d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find_all(class_='article-meta-value')[0].text)
        print('時間: ' + r.find_all(class_='article-meta-value')[-1].text)
        print()
    except:
        continue
