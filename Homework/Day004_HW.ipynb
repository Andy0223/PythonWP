# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"15826593546","type":"PushEvent","actor":{"id":64567828,"login":"haisenberg","display_login":"haisenberg","gravatar_id":"","url":"https://api.github.com/users/haisenberg","avatar_url":"https://avatars.githubusercontent.com/u/64567828?"},"repo":{"id":355099284,"name":"haisenberg/enumerator","url":"https://api.github.com/repos/haisenberg/enumerator"},"payload":{"push_id":6854763044,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"3268e8c08ccec298d158438c0d9c59e4b6649438","before":"e9aa36222ddf04b17d5e10a58e638cc6cabeb0ab","commits":[{"sha":"3268e8c08ccec298d158438c0d9c59e4b6649438","author":{"email":"64567828+haisenberg@users.noreply.github.com","name":"† H"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/haisenberg/enumerator/commits/3268e8c08ccec298d158438c0d9c59e4b6649438"}]},"public":true,"created_at":"2021-04-06T07:38:09Z"},{"id":"15826593522","type":"PushEvent","actor":{"id":39814207,"login":"pull[bot]","display_login":"pull","gravatar_id":"","url":"https://api.github.com/users/pull[bot]","avatar_url":"https://avatars.githubusercontent.com/u/39814207?"},"repo":{"id":337651245,"name":"rinho1239104/lede","url":"https://api.github.com/repos/rinho1239104/lede"},"payload":{"push_id":6854763036,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"6fe4db3814dae9e664f30aaf5108065d79320aaf","before":"049e623690fa27beca5f58fce7428605af9db8c2","commits":[{"sha":"6fe4db3814dae9e664f30aaf5108065d79320aaf","author":{"email":"jimmy591986780@qq.com","name":"Eason"},"message":"Fix luci-app-zerotier iptables bug (#6650)","distinct":true,"url":"https://api.github.com/repos/rinho1239104/lede/commits/6fe4db3814dae9e664f30aaf5108065d79320aaf"}]},"public":true,"created_at":"2021-04-06T07:38:09Z"},{"id":"15826593533","type":"CreateEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":244315971,"name":"kienstra/easy-survey","url":"https://api.github.com/repos/kienstra/easy-survey"},"payload":{"ref":"dependabot/npm_and_yarn/wordpress/editor-9.25.11","ref_type":"branch","master_branch":"develop","description":"A survey block, to explore front-end React rendering","pusher_type":"user"},"public":true,"created_at":"2021-04-06T07:38:09Z"},{"id":"15826593528","type":"CreateEvent","actor":{"id":29236686,"login":"Harsha70","display_login":"Harsha70","gravatar_id":"","url":"https://api.github.com/users/Harsha70","avatar_url":"https://avatars.githubusercontent.com/u/29236686?"},"repo":{"id":355096169,"name":"Harsha70/Super-store","url":"https://api.github.com/repos/Harsha70/Super-store"},"payload":{"ref":"phase-3","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-04-06T07:38:09Z"},{"id":"15826593523","type":"CreateEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":262963790,"name":"mei23/misskey-v11","url":"https://api.github.com/repos/mei23/misskey-v11"},"payload":{"ref":"dependabot/npm_and_yarn/aws-sdk-2.880.0","ref_type":"branch","master_branch":"mei-v11","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-04-06T07:38:09Z"},{"id":"15826593514","type":"PushEvent","actor":{"id":29708070,"login":"AMTitan","display_login":"AMTitan","gravatar_id":"","url":"https://api.github.com/users/AMTitan","avatar_url":"https://avatars.githubusercontent.com/u/29708070?"},"repo":{"id":335998483,"name":"AMTitan/AMTitan","url":"https://api.github.com/repos/AMTitan/AMTitan"},"payload":{"push_id":6854763028,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"69f448ac2b7481153a3275afefbc596fbeddb9d5","before":"588e1cd3ca ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '15826593546',
#   'type': 'PushEvent',
#   'actor': {'id': 64567828,
#    'login': 'haisenberg',
#    'display_login': 'haisenberg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haisenberg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64567828?'},
#   'repo': {'id': 355099284,
#    'name': 'haisenberg/enumerator',
#    'url': 'https://api.github.com/repos/haisenberg/enumerator'},
#   'payload': {'push_id': 6854763044,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3268e8c08ccec298d158438c0d9c59e4b6649438',
#    'before': 'e9aa36222ddf04b17d5e10a58e638cc6cabeb0ab',
#    'commits': [{'sha': '3268e8c08ccec298d158438c0d9c59e4b6649438',
#      'author': {'email': '64567828+haisenberg@users.noreply.github.com',
#       'name': '† H'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/haisenberg/enumerator/commits/3268e8c08ccec298d158438c0d9c59e4b6649438'}]},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593522',
#   'type': 'PushEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 337651245,
#    'name': 'rinho1239104/lede',
#    'url': 'https://api.github.com/repos/rinho1239104/lede'},
#   'payload': {'push_id': 6854763036,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6fe4db3814dae9e664f30aaf5108065d79320aaf',
#    'before': '049e623690fa27beca5f58fce7428605af9db8c2',
#    'commits': [{'sha': '6fe4db3814dae9e664f30aaf5108065d79320aaf',
#      'author': {'email': 'jimmy591986780@qq.com', 'name': 'Eason'},
#      'message': 'Fix luci-app-zerotier iptables bug (#6650)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rinho1239104/lede/commits/6fe4db3814dae9e664f30aaf5108065d79320aaf'}]},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593533',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 244315971,
#    'name': 'kienstra/easy-survey',
#    'url': 'https://api.github.com/repos/kienstra/easy-survey'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/wordpress/editor-9.25.11',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': 'A survey block, to explore front-end React rendering',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593528',
#   'type': 'CreateEvent',
#   'actor': {'id': 29236686,
#    'login': 'Harsha70',
#    'display_login': 'Harsha70',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Harsha70',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29236686?'},
#   'repo': {'id': 355096169,
#    'name': 'Harsha70/Super-store',
#    'url': 'https://api.github.com/repos/Harsha70/Super-store'},
#   'payload': {'ref': 'phase-3',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593523',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 262963790,
#    'name': 'mei23/misskey-v11',
#    'url': 'https://api.github.com/repos/mei23/misskey-v11'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/aws-sdk-2.880.0',
#    'ref_type': 'branch',
#    'master_branch': 'mei-v11',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593514',
#   'type': 'PushEvent',
#   'actor': {'id': 29708070,
#    'login': 'AMTitan',
#    'display_login': 'AMTitan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AMTitan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29708070?'},
#   'repo': {'id': 335998483,
#    'name': 'AMTitan/AMTitan',
#    'url': 'https://api.github.com/repos/AMTitan/AMTitan'},
#   'payload': {'push_id': 6854763028,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '69f448ac2b7481153a3275afefbc596fbeddb9d5',
#    'before': '588e1cd3cae8f787a2764735f4c209138954fb7e',
#    'commits': [{'sha': '69f448ac2b7481153a3275afefbc596fbeddb9d5',
#      'author': {'email': 'actions@users.noreply.github.com',
#       'name': 'Automated Publisher'},
#      'message': 'Automated publish: Tue Apr  6 07:38:06 UTC 2021 588e1cd3cae8f787a2764735f4c209138954fb7e',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AMTitan/AMTitan/commits/69f448ac2b7481153a3275afefbc596fbeddb9d5'}]},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593513',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 264190944,
#    'name': 'Lombiq/Orchard.AngularJS',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard.AngularJS'},
#   'payload': {'push_id': 6854763020,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '8689e53c075bce501577316268adf2e29e9a3784',
#    'before': '8689e53c075bce501577316268adf2e29e9a3784',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '15826593506',
#   'type': 'PushEvent',
#   'actor': {'id': 22763678,
#    'login': 'rozierguillaume',
#    'display_login': 'rozierguillaume',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rozierguillaume',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22763678?'},
#   'repo': {'id': 352545893,
#    'name': 'rozierguillaume/vitemadose',
#    'url': 'https://api.github.com/repos/rozierguillaume/vitemadose'},
#   'payload': {'push_id': 6854763024,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '1a1031b2cad06c3fdad23fd3224c552d3f0c2938',
#    'before': '30d5335c7cd37343d0e47966c9503efad6c3b367',
#    'commits': [{'sha': 'b9711b28614e25d61121758d6dae554574886081',
#      'author': {'email': 'rozierguillaume@users.noreply.github.com',
#       'name': 'rozierguillaume'},
#      'message': '[create-pull-request] automated change',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rozierguillaume/vitemadose/commits/b9711b28614e25d61121758d6dae554574886081'},
#     {'sha': '1a1031b2cad06c3fdad23fd3224c552d3f0c2938',
#      'author': {'email': '28guillaume28@gmail.com',
#       'name': 'Guillaume Rozier'},
#      'message': 'Auto Pull Request (dose_finder2)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rozierguillaume/vitemadose/commits/1a1031b2cad06c3fdad23fd3224c552d3f0c2938'}]},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593508',
#   'type': 'CreateEvent',
#   'actor': {'id': 37415010,
#    'login': 'Soumyadeep65',
#    'display_login': 'Soumyadeep65',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Soumyadeep65',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37415010?'},
#   'repo': {'id': 355100279,
#    'name': 'Soumyadeep65/Soumyadeep65',
#    'url': 'https://api.github.com/repos/Soumyadeep65/Soumyadeep65'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Config files for my GitHub profile.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593500',
#   'type': 'WatchEvent',
#   'actor': {'id': 9260067,
#    'login': 'seongminp',
#    'display_login': 'seongminp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seongminp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9260067?'},
#   'repo': {'id': 185976303,
#    'name': 'antoine77340/video_feature_extractor',
#    'url': 'https://api.github.com/repos/antoine77340/video_feature_extractor'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593505',
#   'type': 'PushEvent',
#   'actor': {'id': 39105103,
#    'login': 'Patil-Onkar',
#    'display_login': 'Patil-Onkar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Patil-Onkar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39105103?'},
#   'repo': {'id': 354859050,
#    'name': 'Patil-Onkar/Capstone-Project-2',
#    'url': 'https://api.github.com/repos/Patil-Onkar/Capstone-Project-2'},
#   'payload': {'push_id': 6854763025,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '53a9a75335c876b90c61c0e4f9293d0ddd5b8265',
#    'before': 'a07b7cfd40d00a1be43145b4d10b29409cf213a7',
#    'commits': [{'sha': '53a9a75335c876b90c61c0e4f9293d0ddd5b8265',
#      'author': {'email': '39105103+Patil-Onkar@users.noreply.github.com',
#       'name': 'Onkar Patil'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Patil-Onkar/Capstone-Project-2/commits/53a9a75335c876b90c61c0e4f9293d0ddd5b8265'}]},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593492',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 72046388,
#    'login': 'Cribb87',
#    'display_login': 'Cribb87',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Cribb87',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72046388?'},
#   'repo': {'id': 351357076,
#    'name': 'Java-Kvalit-grupp-4/hakim_webshop',
#    'url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop'},
#   'payload': {'action': 'closed',
#    'number': 40,
#    'pull_request': {'url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/40',
#     'id': 609594524,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjA5NTk0NTI0',
#     'html_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop/pull/40',
#     'diff_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop/pull/40.diff',
#     'patch_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop/pull/40.patch',
#     'issue_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/40',
#     'number': 40,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Task 57',
#     'user': {'login': 'Cribb87',
#      'id': 72046388,
#      'node_id': 'MDQ6VXNlcjcyMDQ2Mzg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/72046388?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Cribb87',
#      'html_url': 'https://github.com/Cribb87',
#      'followers_url': 'https://api.github.com/users/Cribb87/followers',
#      'following_url': 'https://api.github.com/users/Cribb87/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Cribb87/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Cribb87/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Cribb87/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Cribb87/orgs',
#      'repos_url': 'https://api.github.com/users/Cribb87/repos',
#      'events_url': 'https://api.github.com/users/Cribb87/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Cribb87/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2021-04-06T07:37:56Z',
#     'updated_at': '2021-04-06T07:38:09Z',
#     'closed_at': '2021-04-06T07:38:09Z',
#     'merged_at': '2021-04-06T07:38:09Z',
#     'merge_commit_sha': '25859a35d4780edae6dda9384d6d0146bd44d2b8',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/40/commits',
#     'review_comments_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/40/comments',
#     'review_comment_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/40/comments',
#     'statuses_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/statuses/922a20e4f5671df98c249595de73fa897471445c',
#     'head': {'label': 'Java-Kvalit-grupp-4:task_57',
#      'ref': 'task_57',
#      'sha': '922a20e4f5671df98c249595de73fa897471445c',
#      'user': {'login': 'Java-Kvalit-grupp-4',
#       'id': 80888425,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgwODg4NDI1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/80888425?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Java-Kvalit-grupp-4',
#       'html_url': 'https://github.com/Java-Kvalit-grupp-4',
#       'followers_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/followers',
#       'following_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/orgs',
#       'repos_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/repos',
#       'events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 351357076,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNTEzNTcwNzY=',
#       'name': 'hakim_webshop',
#       'full_name': 'Java-Kvalit-grupp-4/hakim_webshop',
#       'private': False,
#       'owner': {'login': 'Java-Kvalit-grupp-4',
#        'id': 80888425,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgwODg4NDI1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/80888425?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Java-Kvalit-grupp-4',
#        'html_url': 'https://github.com/Java-Kvalit-grupp-4',
#        'followers_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/followers',
#        'following_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/orgs',
#        'repos_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/repos',
#        'events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop',
#       'description': 'School project',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop',
#       'forks_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/forks',
#       'keys_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/teams',
#       'hooks_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/events',
#       'assignees_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/tags',
#       'blobs_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/languages',
#       'stargazers_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/subscription',
#       'commits_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/merges',
#       'archive_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/downloads',
#       'issues_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/deployments',
#       'created_at': '2021-03-25T08:12:51Z',
#       'updated_at': '2021-04-06T07:35:02Z',
#       'pushed_at': '2021-04-06T07:38:09Z',
#       'git_url': 'git://github.com/Java-Kvalit-grupp-4/hakim_webshop.git',
#       'ssh_url': 'git@github.com:Java-Kvalit-grupp-4/hakim_webshop.git',
#       'clone_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop.git',
#       'svn_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop',
#       'homepage': None,
#       'size': 303,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'Java-Kvalit-grupp-4:main',
#      'ref': 'main',
#      'sha': '1b612b116a69f60e7abaf4bc05acc80dcb806fd8',
#      'user': {'login': 'Java-Kvalit-grupp-4',
#       'id': 80888425,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgwODg4NDI1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/80888425?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Java-Kvalit-grupp-4',
#       'html_url': 'https://github.com/Java-Kvalit-grupp-4',
#       'followers_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/followers',
#       'following_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/orgs',
#       'repos_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/repos',
#       'events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 351357076,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNTEzNTcwNzY=',
#       'name': 'hakim_webshop',
#       'full_name': 'Java-Kvalit-grupp-4/hakim_webshop',
#       'private': False,
#       'owner': {'login': 'Java-Kvalit-grupp-4',
#        'id': 80888425,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgwODg4NDI1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/80888425?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Java-Kvalit-grupp-4',
#        'html_url': 'https://github.com/Java-Kvalit-grupp-4',
#        'followers_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/followers',
#        'following_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/orgs',
#        'repos_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/repos',
#        'events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Java-Kvalit-grupp-4/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop',
#       'description': 'School project',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop',
#       'forks_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/forks',
#       'keys_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/teams',
#       'hooks_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/events',
#       'assignees_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/tags',
#       'blobs_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/languages',
#       'stargazers_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/subscription',
#       'commits_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/merges',
#       'archive_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/downloads',
#       'issues_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/deployments',
#       'created_at': '2021-03-25T08:12:51Z',
#       'updated_at': '2021-04-06T07:35:02Z',
#       'pushed_at': '2021-04-06T07:38:09Z',
#       'git_url': 'git://github.com/Java-Kvalit-grupp-4/hakim_webshop.git',
#       'ssh_url': 'git@github.com:Java-Kvalit-grupp-4/hakim_webshop.git',
#       'clone_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop.git',
#       'svn_url': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop',
#       'homepage': None,
#       'size': 303,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/40'},
#      'html': {'href': 'https://github.com/Java-Kvalit-grupp-4/hakim_webshop/pull/40'},
#      'issue': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/40'},
#      'comments': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/issues/40/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/40/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/pulls/40/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Java-Kvalit-grupp-4/hakim_webshop/statuses/922a20e4f5671df98c249595de73fa897471445c'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'Cribb87',
#      'id': 72046388,
#      'node_id': 'MDQ6VXNlcjcyMDQ2Mzg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/72046388?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Cribb87',
#      'html_url': 'https://github.com/Cribb87',
#      'followers_url': 'https://api.github.com/users/Cribb87/followers',
#      'following_url': 'https://api.github.com/users/Cribb87/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Cribb87/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Cribb87/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Cribb87/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Cribb87/orgs',
#      'repos_url': 'https://api.github.com/users/Cribb87/repos',
#      'events_url': 'https://api.github.com/users/Cribb87/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Cribb87/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 9,
#     'additions': 296,
#     'deletions': 1,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z',
#   'org': {'id': 80888425,
#    'login': 'Java-Kvalit-grupp-4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Java-Kvalit-grupp-4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80888425?'}},
#  {'id': '15826593497',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 244315971,
#    'name': 'kienstra/easy-survey',
#    'url': 'https://api.github.com/repos/kienstra/easy-survey'},
#   'payload': {'action': 'opened',
#    'number': 234,
#    'pull_request': {'url': 'https://api.github.com/repos/kienstra/easy-survey/pulls/234',
#     'id': 609594859,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjA5NTk0ODU5',
#     'html_url': 'https://github.com/kienstra/easy-survey/pull/234',
#     'diff_url': 'https://github.com/kienstra/easy-survey/pull/234.diff',
#     'patch_url': 'https://github.com/kienstra/easy-survey/pull/234.patch',
#     'issue_url': 'https://api.github.com/repos/kienstra/easy-survey/issues/234',
#     'number': 234,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @wordpress/editor from 9.19.0 to 9.25.11',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@wordpress/editor](https://github.com/WordPress/gutenberg/tree/HEAD/packages/editor) from 9.19.0 to 9.25.11.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/WordPress/gutenberg/commit/b46033c6a1f28897b809cd1b1c43241544f7a940"><code>b46033c</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/a56ed29096f92fe434f9f0a88d9ab76479ee5ec1"><code>a56ed29</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/244dd6ef2ffd553519ea54cf4e8b1fd1a0d0a671"><code>244dd6e</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/ce7edb7e9277bd154015810adddb6868cfdcfa10"><code>ce7edb7</code></a> Add enableCustomSpacing to block editor settings (<a href="https://github.com/WordPress/gutenberg/tree/HEAD/packages/editor/issues/29277">#29277</a>)</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/e85195cdf43bc0e51287bd11dc5dc99e46b681d5"><code>e85195c</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/ba035ca193acfb5f613999998c94dffd5e53b82d"><code>ba035ca</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/afbb28d78b3209c9468e73424b3f9f3ae8797750"><code>afbb28d</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/76eba7cb18dbb129b1b1ddf9fd4a8a87bace0962"><code>76eba7c</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/4969c8634b41d3229a6c49886fa0eab24311d7a6"><code>4969c86</code></a> chore(release): publish</li>\n<li><a href="https://github.com/WordPress/gutenberg/commit/c79ef3aaa212f328a7d45f02018c21c94aa0965c"><code>c79ef3a</code></a> chore(release): publish</li>\n<li>Additional commits viewable in <a href="https://github.com/WordPress/gutenberg/commits/@wordpress/editor@9.25.11/packages/editor">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=@wordpress/editor&package-manager=npm_and_yarn&previous-version=9.19.0&new-version=9.25.11)](https://dependabot.com/compatibility-score/?dependency-name=@wordpress/editor&package-manager=npm_and_yarn&previous-version=9.19.0&new-version=9.25.11)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this re ...
#     'created_at': '2021-04-06T07:38:09Z',
#     'updated_at': '2021-04-06T07:38:09Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/kienstra/easy-survey/pulls/234/commits',
#     'review_comments_url': 'https://api.github.com/repos/kienstra/easy-survey/pulls/234/comments',
#     'review_comment_url': 'https://api.github.com/repos/kienstra/easy-survey/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/kienstra/easy-survey/issues/234/comments',
#     'statuses_url': 'https://api.github.com/repos/kienstra/easy-survey/statuses/6d5fc8b8b63593c3f51a03c7547af5ace16de39a',
#     'head': {'label': 'kienstra:dependabot/npm_and_yarn/wordpress/editor-9.25.11',
#      'ref': 'dependabot/npm_and_yarn/wordpress/editor-9.25.11',
#      'sha': '6d5fc8b8b63593c3f51a03c7547af5ace16de39a',
#      'user': {'login': 'kienstra',
#       'id': 4063887,
#       'node_id': 'MDQ6VXNlcjQwNjM4ODc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/4063887?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kienstra',
#       'html_url': 'https://github.com/kienstra',
#       'followers_url': 'https://api.github.com/users/kienstra/followers',
#       'following_url': 'https://api.github.com/users/kienstra/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kienstra/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kienstra/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kienstra/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kienstra/orgs',
#       'repos_url': 'https://api.github.com/users/kienstra/repos',
#       'events_url': 'https://api.github.com/users/kienstra/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kienstra/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 244315971,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQzMTU5NzE=',
#       'name': 'easy-survey',
#       'full_name': 'kienstra/easy-survey',
#       'private': False,
#       'owner': {'login': 'kienstra',
#        'id': 4063887,
#        'node_id': 'MDQ6VXNlcjQwNjM4ODc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/4063887?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kienstra',
#        'html_url': 'https://github.com/kienstra',
#        'followers_url': 'https://api.github.com/users/kienstra/followers',
#        'following_url': 'https://api.github.com/users/kienstra/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kienstra/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kienstra/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kienstra/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kienstra/orgs',
#        'repos_url': 'https://api.github.com/users/kienstra/repos',
#        'events_url': 'https://api.github.com/users/kienstra/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kienstra/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/kienstra/easy-survey',
#       'description': 'A survey block, to explore front-end React rendering',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kienstra/easy-survey',
#       'forks_url': 'https://api.github.com/repos/kienstra/easy-survey/forks',
#       'keys_url': 'https://api.github.com/repos/kienstra/easy-survey/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kienstra/easy-survey/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kienstra/easy-survey/teams',
#       'hooks_url': 'https://api.github.com/repos/kienstra/easy-survey/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kienstra/easy-survey/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kienstra/easy-survey/events',
#       'assignees_url': 'https://api.github.com/repos/kienstra/easy-survey/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kienstra/easy-survey/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kienstra/easy-survey/tags',
#       'blobs_url': 'https://api.github.com/repos/kienstra/easy-survey/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kienstra/easy-survey/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kienstra/easy-survey/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kienstra/easy-survey/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kienstra/easy-survey/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kienstra/easy-survey/languages',
#       'stargazers_url': 'https://api.github.com/repos/kienstra/easy-survey/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kienstra/easy-survey/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kienstra/easy-survey/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kienstra/easy-survey/subscription',
#       'commits_url': 'https://api.github.com/repos/kienstra/easy-survey/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kienstra/easy-survey/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kienstra/easy-survey/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kienstra/easy-survey/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kienstra/easy-survey/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kienstra/easy-survey/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kienstra/easy-survey/merges',
#       'archive_url': 'https://api.github.com/repos/kienstra/easy-survey/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kienstra/easy-survey/downloads',
#       'issues_url': 'https://api.github.com/repos/kienstra/easy-survey/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kienstra/easy-survey/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kienstra/easy-survey/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kienstra/easy-survey/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kienstra/easy-survey/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kienstra/easy-survey/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kienstra/easy-survey/deployments',
#       'created_at': '2020-03-02T08:17:33Z',
#       'updated_at': '2020-07-15T22:45:13Z',
#       'pushed_at': '2021-04-06T07:38:08Z',
#       'git_url': 'git://github.com/kienstra/easy-survey.git',
#       'ssh_url': 'git@github.com:kienstra/easy-survey.git',
#       'clone_url': 'https://github.com/kienstra/easy-survey.git',
#       'svn_url': 'https://github.com/kienstra/easy-survey',
#       'homepage': None,
#       'size': 4124,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 17,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 0,
#       'open_issues': 17,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     'base': {'label': 'kienstra:develop',
#      'ref': 'develop',
#      'sha': '080c0fe6273ca2503dacc61b4f8bb45efdba34b2',
#      'user': {'login': 'kienstra',
#       'id': 4063887,
#       'node_id': 'MDQ6VXNlcjQwNjM4ODc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/4063887?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kienstra',
#       'html_url': 'https://github.com/kienstra',
#       'followers_url': 'https://api.github.com/users/kienstra/followers',
#       'following_url': 'https://api.github.com/users/kienstra/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kienstra/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kienstra/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kienstra/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kienstra/orgs',
#       'repos_url': 'https://api.github.com/users/kienstra/repos',
#       'events_url': 'https://api.github.com/users/kienstra/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kienstra/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 244315971,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQzMTU5NzE=',
#       'name': 'easy-survey',
#       'full_name': 'kienstra/easy-survey',
#       'private': False,
#       'owner': {'login': 'kienstra',
#        'id': 4063887,
#        'node_id': 'MDQ6VXNlcjQwNjM4ODc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/4063887?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kienstra',
#        'html_url': 'https://github.com/kienstra',
#        'followers_url': 'https://api.github.com/users/kienstra/followers',
#        'following_url': 'https://api.github.com/users/kienstra/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kienstra/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kienstra/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kienstra/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kienstra/orgs',
#        'repos_url': 'https://api.github.com/users/kienstra/repos',
#        'events_url': 'https://api.github.com/users/kienstra/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kienstra/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/kienstra/easy-survey',
#       'description': 'A survey block, to explore front-end React rendering',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kienstra/easy-survey',
#       'forks_url': 'https://api.github.com/repos/kienstra/easy-survey/forks',
# ...
#       'repos_url': 'https://api.github.com/users/sophiemoustard/repos',
#       'events_url': 'https://api.github.com/users/sophiemoustard/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sophiemoustard/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 102373090,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDIzNzMwOTA=',
#       'name': 'alenvi-api',
#       'full_name': 'sophiemoustard/alenvi-api',
#       'private': False,
#       'owner': {'login': 'sophiemoustard',
#        'id': 24521863,
#        'node_id': 'MDQ6VXNlcjI0NTIxODYz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/24521863?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sophiemoustard',
#        'html_url': 'https://github.com/sophiemoustard',
#        'followers_url': 'https://api.github.com/users/sophiemoustard/followers',
#        'following_url': 'https://api.github.com/users/sophiemoustard/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sophiemoustard/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sophiemoustard/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sophiemoustard/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sophiemoustard/orgs',
#        'repos_url': 'https://api.github.com/users/sophiemoustard/repos',
#        'events_url': 'https://api.github.com/users/sophiemoustard/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sophiemoustard/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/sophiemoustard/alenvi-api',
#       'description': 'Alenvi API (NodeJS + Hapi)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/sophiemoustard/alenvi-api',
#       'forks_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/forks',
#       'keys_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/teams',
#       'hooks_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/hooks',
#       'issue_events_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/events',
#       'assignees_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/tags',
#       'blobs_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/languages',
#       'stargazers_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/stargazers',
#       'contributors_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/contributors',
#       'subscribers_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/subscribers',
#       'subscription_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/subscription',
#       'commits_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/merges',
#       'archive_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/downloads',
#       'issues_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/deployments',
#       'created_at': '2017-09-04T14:59:01Z',
#       'updated_at': '2021-03-30T10:39:55Z',
#       'pushed_at': '2021-04-06T06:46:05Z',
#       'git_url': 'git://github.com/sophiemoustard/alenvi-api.git',
#       'ssh_url': 'git@github.com:sophiemoustard/alenvi-api.git',
#       'clone_url': 'https://github.com/sophiemoustard/alenvi-api.git',
#       'svn_url': 'https://github.com/sophiemoustard/alenvi-api',
#       'homepage': '',
#       'size': 7841,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'sophiemoustard:dev',
#      'ref': 'dev',
#      'sha': 'ceed8db0bea57781070f369ad6b549cf4e6889a2',
#      'user': {'login': 'sophiemoustard',
#       'id': 24521863,
#       'node_id': 'MDQ6VXNlcjI0NTIxODYz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/24521863?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sophiemoustard',
#       'html_url': 'https://github.com/sophiemoustard',
#       'followers_url': 'https://api.github.com/users/sophiemoustard/followers',
#       'following_url': 'https://api.github.com/users/sophiemoustard/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sophiemoustard/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sophiemoustard/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sophiemoustard/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sophiemoustard/orgs',
#       'repos_url': 'https://api.github.com/users/sophiemoustard/repos',
#       'events_url': 'https://api.github.com/users/sophiemoustard/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sophiemoustard/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 102373090,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDIzNzMwOTA=',
#       'name': 'alenvi-api',
#       'full_name': 'sophiemoustard/alenvi-api',
#       'private': False,
#       'owner': {'login': 'sophiemoustard',
#        'id': 24521863,
#        'node_id': 'MDQ6VXNlcjI0NTIxODYz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/24521863?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sophiemoustard',
#        'html_url': 'https://github.com/sophiemoustard',
#        'followers_url': 'https://api.github.com/users/sophiemoustard/followers',
#        'following_url': 'https://api.github.com/users/sophiemoustard/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sophiemoustard/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sophiemoustard/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sophiemoustard/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sophiemoustard/orgs',
#        'repos_url': 'https://api.github.com/users/sophiemoustard/repos',
#        'events_url': 'https://api.github.com/users/sophiemoustard/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sophiemoustard/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/sophiemoustard/alenvi-api',
#       'description': 'Alenvi API (NodeJS + Hapi)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/sophiemoustard/alenvi-api',
#       'forks_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/forks',
#       'keys_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/teams',
#       'hooks_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/hooks',
#       'issue_events_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/events',
#       'assignees_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/tags',
#       'blobs_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/languages',
#       'stargazers_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/stargazers',
#       'contributors_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/contributors',
#       'subscribers_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/subscribers',
#       'subscription_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/subscription',
#       'commits_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/merges',
#       'archive_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/downloads',
#       'issues_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/sophiemoustard/alenvi-api/deployments',
#       'created_at': '2017-09-04T14:59:01Z',
#       'updated_at': '2021-03-30T10:39:55Z',
#       'pushed_at': '2021-04-06T06:46:05Z',
#       'git_url': 'git://github.com/sophiemoustard/alenvi-api.git',
#       'ssh_url': 'git@github.com:sophiemoustard/alenvi-api.git',
#       'clone_url': 'https://github.com/sophiemoustard/alenvi-api.git',
#       'svn_url': 'https://github.com/sophiemoustard/alenvi-api',
#       'homepage': '',
#       'size': 7841,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/pulls/1356'},
#      'html': {'href': 'https://github.com/sophiemoustard/alenvi-api/pull/1356'},
#      'issue': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues/1356'},
#      'comments': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/issues/1356/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/pulls/1356/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/pulls/1356/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/sophiemoustard/alenvi-api/statuses/ab11fe368b3ba2ce7b55f5ea3d0abfb7fed1d00a'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-04-06T07:38:08Z'},
#  {'id': '15826593435',
#   'type': 'WatchEvent',
#   'actor': {'id': 3918488,
#    'login': 'chrishelgert',
#    'display_login': 'chrishelgert',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chrishelgert',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3918488?'},
#   'repo': {'id': 61137153,
#    'name': 'evanw/esbuild',
#    'url': 'https://api.github.com/repos/evanw/esbuild'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z'},
#  {'id': '15826593413',
#   'type': 'CreateEvent',
#   'actor': {'id': 1571330,
#    'login': 'jan-kiszka',
#    'display_login': 'jan-kiszka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jan-kiszka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1571330?'},
#   'repo': {'id': 262497269,
#    'name': 'siemens/meta-iot2050',
#    'url': 'https://api.github.com/repos/siemens/meta-iot2050'},
#   'payload': {'ref': 'jan/usb-modems',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'SIMATIC IOT2050 Isar/Debian Board Support Package',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-04-06T07:38:09Z',
#   'org': {'id': 624020,
#    'login': 'siemens',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/siemens',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/624020?'}}]

# %% [markdown]
# ### 兩者差異
# #### 透過 request.get() 讀出來的是 str 型態的資料
# #### 透過 json.loads() 讀出來的是 dict(字典) 型態的資料

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-606c136a-1a77a46c63792e150b1832f2'},
#  'origin': '220.137.160.24',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-606c1686-496e7f5a023ee9686f5a52db'},
#  'json': None,
#  'origin': '220.137.160.24',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容：
# ### 串接政府開放資料平台：即時水位資料

# %%
r1 = requests.post('https://data.wra.gov.tw/Service/OpenData.aspx?format=json&id=2D09DB8B-6A1B-485E-88B5-923A462F475C',data = {'key':'value'})
json.loads(r1.text)
# Out:
# {'RealtimeWaterLevel_OPENDATA': [{'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H001',
#    'WaterLevel': '684.32'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H002',
#    'WaterLevel': '530.69'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H041',
#    'WaterLevel': '830.27'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H043',
#    'WaterLevel': '439.44'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H048',
#    'WaterLevel': '28.19'},
#   {'RecordTime': '2021-04-06T16:00:00',
#    'StationIdentifier': '1140H049',
#    'WaterLevel': '22.11'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H054',
#    'WaterLevel': '246.55'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H058',
#    'WaterLevel': '3.97'},
#   {'RecordTime': '2021-04-06T16:00:00',
#    'StationIdentifier': '1140H066',
#    'WaterLevel': '1.93'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H067',
#    'WaterLevel': '28.84'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H068',
#    'WaterLevel': '48.92'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H076',
#    'WaterLevel': '135.46'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H082',
#    'WaterLevel': '6.77'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H089',
#    'WaterLevel': '0.00'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H095',
#    'WaterLevel': '109.60'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H096',
#    'WaterLevel': '170.35'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H097',
#    'WaterLevel': '171.75'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H098',
#    'WaterLevel': '174.43'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': '263.27'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H101',
#    'WaterLevel': '181.81'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H102',
#    'WaterLevel': '208.82'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H105',
#    'WaterLevel': '-0.09'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': '49.04'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H107',
#    'WaterLevel': '2.45'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': '11.82'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H109',
#    'WaterLevel': '48.85'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1140H110',
#    'WaterLevel': '42.12'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H126',
#    'WaterLevel': '80.76'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H127',
#    'WaterLevel': '33.05'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H128',
#    'WaterLevel': '19.23'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1140H129',
#    'WaterLevel': '27.66'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1270H001',
#    'WaterLevel': '22.48'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1280H001',
#    'WaterLevel': '72.10'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': '40.81'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1290H004',
#    'WaterLevel': '115.81'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1290H006',
#    'WaterLevel': '66.26'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1290H007',
#    'WaterLevel': '12.36'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H013',
#    'WaterLevel': '245.65'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H014',
#    'WaterLevel': '208.87'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H016',
#    'WaterLevel': '100.69'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H017',
#    'WaterLevel': '26.80'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H018',
#    'WaterLevel': '96.32'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H019',
#    'WaterLevel': '86.23'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H020',
#    'WaterLevel': '251.31'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H021',
#    'WaterLevel': '0.40'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': '-0.06'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H023',
#    'WaterLevel': '52.35'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1300H024',
#    'WaterLevel': '28.86'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1310H001',
#    'WaterLevel': '12.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1310H002',
#    'WaterLevel': '0.98'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1320H001',
#    'WaterLevel': '2.69'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1320H002',
#    'WaterLevel': '16.85'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H008',
#    'WaterLevel': '37.93'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H009',
#    'WaterLevel': '175.78'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H010',
#    'WaterLevel': '0.58'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': '7.49'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H012',
#    'WaterLevel': '246.80'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H013',
#    'WaterLevel': '247.02'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': '0.20'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': '49.93'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1340H016',
#    'WaterLevel': '0.48'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': '169.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H012',
#    'WaterLevel': '12.22'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': '95.30'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H017',
#    'WaterLevel': '243.78'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': '281.97'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H019',
#    'WaterLevel': '33.67'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': '220.63'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H021',
#    'WaterLevel': '319.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H022',
#    'WaterLevel': '253.84'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H023',
#    'WaterLevel': '256.21'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': '259.62'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H025',
#    'WaterLevel': '0.53'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H026',
#    'WaterLevel': '30.40'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': '145.84'},
#   {'RecordTime': '2021-04-06T16:00:00',
#    'StationIdentifier': '1350H028',
#    'WaterLevel': '232.64'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': '175.89'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H030',
#    'WaterLevel': '55.98'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': '0.36'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1400H008',
#    'WaterLevel': '479.48'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': '190.36'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1400H012',
#    'WaterLevel': '598.85'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': '623.13'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1400H018',
#    'WaterLevel': '55.20'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': '310.14'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1400H020',
#    'WaterLevel': '319.12'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': '54.10'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1420H052',
#    'WaterLevel': '429.48'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1420H053',
#    'WaterLevel': '473.07'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': '702.77'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': '319.31'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1420H056',
#    'WaterLevel': '195.06'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': '635.46'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': '440.47'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H025',
#    'WaterLevel': '9.76'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H028',
#    'WaterLevel': '23.47'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': '50.54'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H030',
#    'WaterLevel': '87.03'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H032',
#    'WaterLevel': '337.22'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': '380.31'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H038',
#    'WaterLevel': '75.42'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': '19.12'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H044',
#    'WaterLevel': '138.99'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': '91.44'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H046',
#    'WaterLevel': '111.05'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': '72.16'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H048',
#    'WaterLevel': '165.76'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': '95.66'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H052',
#    'WaterLevel': '172.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H053',
#    'WaterLevel': '38.35'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': '48.44'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H055',
#    'WaterLevel': '77.99'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': '77.37'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H057',
#    'WaterLevel': '31.69'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': '82.84'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H060',
#    'WaterLevel': '19.84'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1430H061',
#    'WaterLevel': '24.92'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': '472.84'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H050',
#    'WaterLevel': '155.02'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H057',
#    'WaterLevel': '87.69'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': '11.40'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H063',
#    'WaterLevel': '263.45'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H064',
#    'WaterLevel': '265.34'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': '20.05'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': '346.18'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H076',
#    'WaterLevel': '4.99'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': '186.37'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': '1068.89'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H081',
#    'WaterLevel': '229.04'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': '751.67'},
#   {'RecordTime': '2021-04-06T16:00:00',
#    'StationIdentifier': '1510H083',
#    'WaterLevel': '116.20'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': '143.12'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H085',
#    'WaterLevel': '279.55'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': '317.26'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H087',
#    'WaterLevel': '427.49'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': '141.01'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': '78.19'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': '0.65'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H014',
#    'WaterLevel': '7.60'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': '12.57'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': '26.76'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H031',
#    'WaterLevel': '9.90'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': '19.86'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': '23.20'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H035',
#    'WaterLevel': '86.32'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H036',
#    'WaterLevel': '0.82'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': '31.87'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H038',
#    'WaterLevel': '54.31'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': '38.98'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1550H011',
#    'WaterLevel': '0.30'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': '0.34'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': '26.73'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1550H016',
#    'WaterLevel': '12.31'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': '15.55'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1550H018',
#    'WaterLevel': '0.74'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': '223.20'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H007',
#    'WaterLevel': '23.64'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': '19.79'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H013',
#    'WaterLevel': '9.64'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H015',
#    'WaterLevel': '22.56'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': '25.72'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': '21.28'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H020',
#    'WaterLevel': '34.90'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': '1.07'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': '0.91'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1590H012',
#    'WaterLevel': '2.54'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': '20.33'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1590H015',
#    'WaterLevel': '9.16'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': '11.00'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1590H019',
#    'WaterLevel': '14.79'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': '41.20'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H013',
#    'WaterLevel': '15.47'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': '9.03'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H020',
#    'WaterLevel': '35.83'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': '0.51'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': '68.98'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H025',
#    'WaterLevel': '1.05'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H026',
#    'WaterLevel': '44.29'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': '26.25'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H028',
#    'WaterLevel': '8.31'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H029',
#    'WaterLevel': '4.50'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': '1.38'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H031',
#    'WaterLevel': '0.82'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': '0.79'},
#   {'RecordTime': '2021-04-06T15:50:00',
#    'StationIdentifier': '1630H033',
#    'WaterLevel': '0.66'},
#   {'RecordTime': '2021-04-06T15:40:00',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': '278.37'},
#   {'RecordTime': '2021-04-06T15:40:00',
#    'StationIdentifier': '1630H035',
#    'WaterLevel': '402.22'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': '65.89'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H037',
#    'WaterLevel': '9.33'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': '1.74'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H006',
#    'WaterLevel': '0.97'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': '0.68'},
#   {'RecordTime': '2021-04-01T14:10:00',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': '-999998.00'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H011',
#    'WaterLevel': '0.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': '5.20'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H014',
#    'WaterLevel': '1.06'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': '0.60'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1650H017',
#    'WaterLevel': '0.73'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': '4.63'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1660H010',
#    'WaterLevel': '7.32'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1660H011',
#    'WaterLevel': '1.35'},
#   {'RecordTime': '2021-04-01T23:40:00',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': '0.38'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1660H013',
#    'WaterLevel': '1.55'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1670H003',
#    'WaterLevel': '0.73'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': '2.96'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1680H004',
#    'WaterLevel': '1.06'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': '0.54'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H036',
#    'WaterLevel': '107.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': '22.43'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H045',
#    'WaterLevel': '4.71'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': '43.16'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H058',
#    'WaterLevel': '113.56'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': '265.94'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H062',
#    'WaterLevel': '41.65'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H065',
#    'WaterLevel': '90.44'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': '138.62'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H067',
#    'WaterLevel': '399.04'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': '10.30'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H069',
#    'WaterLevel': '140.62'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': '226.16'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H071',
#    'WaterLevel': '35.26'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': '248.81'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H074',
#    'WaterLevel': '244.73'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': '93.16'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H076',
#    'WaterLevel': '58.01'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': '739.69'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H079',
#    'WaterLevel': '550.57'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1730H081',
#    'WaterLevel': '-999998.00'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': '4.11'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1740H007',
#    'WaterLevel': '0.90'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1740H008',
#    'WaterLevel': '1.60'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1740H009',
#    'WaterLevel': '33.04'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1740H010',
#    'WaterLevel': '47.30'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1740H011',
#    'WaterLevel': '6.45'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1850H004',
#    'WaterLevel': '72.14'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': '21.97'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H007',
#    'WaterLevel': '157.84'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H011',
#    'WaterLevel': '26.25'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H020',
#    'WaterLevel': '318.27'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H021',
#    'WaterLevel': '369.30'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H022',
#    'WaterLevel': '161.87'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H025',
#    'WaterLevel': '206.68'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': '106.73'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H028',
#    'WaterLevel': '277.54'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': '145.84'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H004',
#    'WaterLevel': '192.55'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H016',
#    'WaterLevel': '167.84'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': '59.13'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': '124.10'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H019',
#    'WaterLevel': '155.46'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H024',
#    'WaterLevel': '195.16'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': '261.64'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H018',
#    'WaterLevel': '156.47'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': '109.81'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H024',
#    'WaterLevel': '4.53'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': '164.29'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H037',
#    'WaterLevel': '132.78'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': '78.63'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2420H046',
#    'WaterLevel': '35.75'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': '31.96'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H006',
#    'WaterLevel': '2.19'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H017',
#    'WaterLevel': '365.02'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': '4.38'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': '0.35'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H022',
#    'WaterLevel': '193.86'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': '13.33'},
#   {'RecordTime': '2021-04-06T16:10:00',
#    'StationIdentifier': '2560H024',
#    'WaterLevel': '201.22'},
#   {'RecordTime': '2021-04-06T16:20:00',
#    'StationIdentifier': '2560H025',
#    'WaterLevel': '2.17'}]}
