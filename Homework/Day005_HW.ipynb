# %% [markdown]
# ### 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
# #### 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# #### 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# #### 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

response
# Out:
# '[{"id":235717437,"title":"(更）沒做功課就不要養寵物！！！","excerpt":"前幾天有個學妹打給我說她養了兔子，學妹：我買了一隻兔子 但牠尿尿在盒子怎麼辦？我：衛生紙擦乾淨就好了，學妹：好 那牠身上也是尿欸 可以洗澡嗎 還是可以給牠噴酒精，我：？？？？三小 會死！！！！擦乾就好","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2021-04-07T07:40:08.988Z","updatedAt":"2021-04-08T14:01:22.002Z","commentCount":51,"likeCount":573,"withNickname":false,"tags":[],"topics":["兔","飼主責任","毛小孩"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"F","school":"台南應用科技大學","replyTitle":null,"mediaMeta":[],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":456},{"id":"aa0d425f-d530-4478-9a77-fe3aedc79eea","count":91},{"id":"514c2569-fd53-4d9d-a415-bf0f88e7329f","count":17},{"id":"4b018f48-e184-445f-adf1-fc8e04ba09b9","count":6},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":3}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"isModerator":false,"layout":"classic","spoilerAlert":false,"withImages":false,"withVideos":false,"media":[],"reportReasonText":"","excerptComments":[],"postAvatar":"","verifiedBadge":false,"memberType":""},{"id":235717926,"title":"貓咪的牙齒！！","excerpt":"我一定要跟大家分享我的喜悅 就算沒人在乎！，我剛剛撿到我們家小笨蛋的牙齒！！，撒花٩（˃̶͈̀௰˂̶͈́）و，他現在五個月大了正在換牙，噹啷～～\\\\（≧▽≦）/，雖然很幸運，剛剛發現的時候去檢查他的嘴巴","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2021-04-07T08:57:00.630Z","updatedAt":"2021-04-07T08:57:00.630Z","commentCount":25,"likeCount":376,"withNickname":true,"tags":[],"topics":["牙齒","貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"F","school":"仙女不纖","department":"a0987.","replyTitle":null,"mediaMeta":[{"id":"94ff5cea-c32c-4124-87ee-184a8a1d29e9","url":"https://i.imgur.com/df1Ddjal.jpg","normalizedUrl":"https://i.imgur.com/df1Ddjal.jpg","thumbnail":"https://i.imgur.com/df1Ddjal.jpg","type":"image/thumbnail","tags":[],"createdAt":"2021-04-07T08:57:00.630Z","updatedAt":"2021-04-07T08:57:00.630Z","width":1500,"height":2000,"croppingWindow":{"anchorX":0,"anchorY":0,"width":1500,"height":2000}},{"id":"94ff5cea-c32c-4124-87ee-184a8a1d29e9","url":"https://i.imgur.com/df1Ddja.jpg","normalizedUrl":"https://imgur.com/df1Ddja","thumbnail":"https://i.imgur.com/df1Ddjal.jpg","type":"image/imgur","tags":[],"createdAt":"2021-04-07T08:57:00.630Z","updatedAt":"2021-04-07T08:57:00.630Z","width":1500,"height":2000,"croppingWindow":{"anchorX":0,"anchorY":0,"width":1500,"height":2000}},{"id":"7534c56c-82a3-4de9-91a9-80653b8fa635","url":"https://i.imgur.com/SK5rNXL.jpg","normalizedUrl":"https://imgur.com/SK5rNXL","thumbnail":"https://i.imgur.com/SK5rNXLl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-04-07T08:57:00.630Z","updatedAt":"2021-04-07T08:57:00.630Z","width":2000,"height":1500},{"id":"59c2348d-d28a-408f-b533-d506cac473fe","url":"https://i.imgur.com/VWbPyRJ.jpg","normalizedUrl":"https://imgur.com/VWbPyRJ","thumbnail":"https://i.imgur.com/VWbPyRJl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-04-07T08:57:00.630Z","updatedAt":"2021-04-07T08:57:00.630Z","width":1500,"height":2000},{"id":"e55dc749-d16b-4a98-ab74-3e9f6b7b5675","url":"https://i.imgur.com/ieXZN5f.jpg","normalizedUrl":"https://imgur.com/ieXZN5f","thumbnail":"https://i.imgur.com/ieXZN5fl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-04-07T08:57:00.630Z","updatedAt":"2021-04-07T08:57:00.630Z","width":1500,"height":2000}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":375},{"id":"4b018f48-e184-445f-adf1-fc8e04ba09b9","count":1}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"isModerator":false,"layout":"classic","spoilerAlert":false,"withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/df1Ddja.jpg"},{"url":"https://i.imgur.com/SK5rNXL.jpg"},{"url":"https://i.imgur.com/VWbPyRJ.jpg"},{"url":"https://i.imgur.com/ieXZN5f.jpg"}],"reportReasonText":"","excerptComments":[],"po ...

# %%
import json
data = json.loads(response)
count = 0
print("這個API總共有",len(data),"筆資料")
print()
print("每一筆資料有以下欄位")
for d in data[0]:
    print(d)
# Out:
# 這個API總共有 30 筆資料
#
# 每一筆資料有以下欄位
# id
# title
# excerpt
# anonymousSchool
# anonymousDepartment
# pinned
# forumId
# replyId
# createdAt
# updatedAt
# commentCount
# likeCount
# withNickname
# tags
# topics
# meta
# forumName
# forumAlias
# nsfw
# gender
# school
# replyTitle
# mediaMeta
# reactions
# hidden
# customStyle
# isSuspiciousAccount
# isModerator
# layout
# spoilerAlert
# withImages
# withVideos
# media
# reportReasonText
# excerptComments
# postAvatar
# verifiedBadge
# memberType

# %%
for d in data:
    print(d['title'],d['createdAt'],d['commentCount'],d['likeCount'])
# Out:
# (更）沒做功課就不要養寵物！！！ 2021-04-07T07:40:08.988Z 51 544
# 貓咪的牙齒！！ 2021-04-07T08:57:00.630Z 25 363
# 貓真的很神奇😂 2021-04-07T11:52:11.705Z 6 331
# 到底誰才是親生的....... 2021-04-07T07:18:29.232Z 6 184
# 貓貓出生囉 2021-04-08T04:53:30.317Z 18 129
# 所謂合法的寵物店/繁殖場/貓舍 2021-04-08T03:52:06.760Z 18 91
# 貓兒第一次去公園 2021-04-07T14:31:48.972Z 11 68
# 貓咪放在那邊是可以的嗎？ 2021-04-07T15:59:16.715Z 18 66
# 奴才你要起床了嗎？ 2021-04-08T06:15:44.282Z 6 64
# 徵求可愛背影 2021-04-07T07:06:48.054Z 39 37
# #求解 貓咪突然變得有點怕人 2021-04-08T02:44:12.845Z 10 33
# 補給大家尾巴照片 2021-04-07T09:57:21.159Z 4 33
# 拜託幫牠們找家 2021-04-07T09:47:42.506Z 3 32
# 愛玩拋接的🐱 2021-04-07T07:24:49.797Z 8 27
# 貓砂漠Bye~好市多豆腐砂開箱😺 2021-04-08T08:34:29.291Z 9 21
# 家里有兩隻愛餽頭的貓貓❤❤ 2021-04-07T12:13:19.729Z 0 20
# 對於拍照逐漸感到無奈的柯基99 2021-04-08T01:47:15.088Z 1 18
# 我家勇敢的小咪 2021-04-07T05:38:47.238Z 0 18
# 請大家盡量分享出去，讓這個人被肉搜找出來 2021-04-08T09:23:47.624Z 3 16
# 來人，上罐罐 2021-04-07T11:54:16.670Z 2 15
# 近期最喜歡的窩 2021-04-08T04:54:15.468Z 6 14
# 沒被小姊姊們嚕夠的後續 2021-04-07T04:41:23.815Z 3 13
# 我們四歲了！ 2021-04-08T14:23:29.907Z 0 11
# （已尋獲）台中大雅急尋！尋貓啟示！！ 2021-04-08T04:55:40.273Z 5 11
# 夏天就是要游泳啊！ 2021-04-07T05:26:32.513Z 0 10
# 貓⋯ 頭鷹？ 2021-04-08T11:45:05.760Z 0 8
# 我沒有胖嘟嘟🥴 2021-04-08T06:01:02.718Z 0 8
# 貓咪真是越調皮越可愛的動物 2021-04-08T03:17:41.919Z 6 8
# 想問貓咪身上是寄生蟲嗎 2021-04-07T18:04:11.456Z 10 6
# 分享我家貓貓 2021-04-08T11:20:05.734Z 2 5

# %%
comment = 0
like = 0
for d in data:
    comment+=d['commentCount']
    like+=d['likeCount']
print(comment / 30)
print(like / 30)
# Out:
# 9.0
# 73.46666666666667

# %%
r1 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
response1 = r1.text
data1 = json.loads(response1)
comment1 = 0
like1 = 0

for d in data1:
    comment1+=d['commentCount']
    like1+=d['likeCount']
print(comment1/30)
print(like1/30)
# Out:
# 2.033333333333333
# 6.8
